# %% [markdown]
# # CSE527 Homework 3 - Part 2
# **Due date: 23:59 on Nov 26, 2023**
#
#
# ## Description
# ---
# Detection is a fundamental task in CV. This homework is on based on DETR (https://arxiv.org/abs/2005.12872), one of the most famous yet simple detection model.
#
# In this part, you will get familiar with DETR code base and will be modfiying the code (https://github.com/facebookresearch/detr/tree/main) to perfrom a new task: **_Detection using Centroids_**.
#
# Traditionally bounding boxes are used to highlight detections, however in this homework you will perfrom detection of an object by selecting a _meaningful_ center point on it. We will call that point the centroid. For applications involving peculiar objects (like Giraffes,), where the center of the bounding box may not lie on the objects main body, a centroid detection may be more useful.

# %% [markdown]
# ## Code
# ---
# Although DETR is simple relative to other detection models, the code to train and test is still complex and is spread acorss multiple directories. For this reason, the code is provided in a zipped package (here [detr.zip](https://drive.google.com/file/d/1GuserI8EDxAlTG4eh98JhugVsSDWCS3f/view?usp=sharing)).
#
# To pull this code into your colab, you have to first add the zip file as shortcut to current working directory. To do this, open the above link and click on "Add shortcut to Drive" button (drive symbol with a plus) and navigate to working current directory and add shortcut.
#
# You have to repeat the same process to download this [coco.zip dataset](https://drive.google.com/file/d/1GVyxYHwVgiG9z_Sn46wslT_2n65DLZRw/view?usp=sharing).

# %%
HW3_ROOT_PATH = '/gdrive/MyDrive/' + 'MUPPARAPU_SAIKOUSHIK_114999629_hw3/' #'FILL IN YOUR HOMEWORK3 ROOT HERE'
PATH_TO_PART2 = HW3_ROOT_PATH + 'part2/'
PATH_TO_COCO = HW3_ROOT_PATH + 'coco/'
# TRY to use these variable wherever you load/save some file

# %%
from google.colab import drive
drive.mount('/gdrive')
# CD into root of your homework2 part2 directory
# %cd -q $PATH_TO_PART2
# Out:
# Mounted at /gdrive

# %%
# !ls
# Out:
# CSE527_23F_HW3_P2.ipynb  detr

# %%
# !unzip -n detr.zip
# Out:
# Archive:  detr.zip

# %%
# %cd detr
# %mkdir checkpoints
# Out:
# /gdrive/MyDrive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/part2/detr
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Install dependencies
# ---
# If you are using colab, running below cell will suffice, else refer to requirements.txt to install all dependencies

# %%
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-gscgibg_
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-gscgibg_
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (67.7.2)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.0.5)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375459 sha256=27307cc4abd723f3762238eca8ee9860f9e56cf6d22b28480faeed5212946c58
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sy8vut4t/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# Successfully installed pycocotools-2.0

# %% [markdown]
# ##Model
# ---
# DETR consists of
# - a feature extractor,
# - transformer and
# - two output heads
#     - classification head
#     - regression head
#
# In the original implementation, regression head is designed to output the bouding box attributes ltrb (left, top, right, & bottom edges of object). In this homework we intend to train the model to output the centeroids of each object.
#
# ###How do we define centroids:###
# Original DETR uses the MS COCO's _bbox_ annotations to train the model, while in this HW we will use the _segmentation_ annotations.
# Each image may have multiple objects. The pixel outline of each object is provided as an annotation. We will use this contour information to generate the object mask.
#
#
# In the below image, you can see that centroid is near the biggest portion of the object body.
# ![](https://drive.google.com/uc?export=view&id=1CNym_GFV8EKwTQPZQSHZdPB7P-3qarEm)

# %% [markdown]
# ## Get yourself familiar with Data set
# ---
#
# To get your self familiar with the dataset, you are encouraged to play around with the COCO API. The sample code  given below displays the segmentation data format. In the later sections you will be yusing the segmentation data to estimate a centroid.

# %%
from pycocotools.coco import COCO
from PIL import Image
from hubconf import _make_detr
import torch
import requests
import numpy as np
import os
import matplotlib.pyplot as plt
import torchvision.transforms as T

coco = COCO('instances_train2017.json')
ids = coco.getImgIds()

sample = 0
im = coco.loadImgs(ids[sample])[0]
print(f'Image keys: {im.keys()}')
annos = coco.loadAnns(coco.getAnnIds(ids[sample]))
# Note: segmentation annotation is in the format of [x1, y1, x2, y2, x3, y3, . . . ], where (x1, y1) is a point
# on countour, x being dist from left and y is dist from top row of image
print(f'Anno segmentation: {(annos[0]["segmentation"])}')
############# (0 points) ########################


#################################################
# Out:
# loading annotations into memory...
# Done (t=1.32s)
# creating index...
# index created!
# Image keys: dict_keys(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'])
# Anno segmentation: [[318.97, 254.35, 328.71, 199.41, 339.35, 164.86, 343.78, 154.23, 336.69, 135.62, 349.09, 145.37, 365.93, 145.37, 372.13, 137.39, 380.1, 145.37, 397.82, 146.25, 436.81, 148.02, 472.25, 159.54, 506.8, 175.49, 536.93, 188.78, 579.46, 202.07, 617.56, 205.62, 640.0, 199.41, 637.94, 349.15, 590.09, 351.81, 547.56, 334.98, 501.49, 317.25, 511.23, 349.15, 510.35, 376.62, 516.55, 407.63, 505.03, 407.63, 498.83, 381.93, 497.94, 407.63, 480.22, 405.86, 474.02, 367.76, 459.85, 316.37, 437.69, 284.47, 432.38, 257.89, 412.89, 230.42, 391.62, 210.05, 380.1, 222.45, 363.27, 233.97, 357.95, 251.69, 346.43, 259.66, 330.49, 264.98]]

# %% [markdown]
# ## Complete the code
# ---
#
# This provided detr/ folder has the following structure
# ```
# detr/
# ├── datasets/
# │   ├── coco.py
# │   ├── ...
# ├── models/
# │   ├── detr.py
# │   ├── matcher.py
# │   └── ...
# ├── utils/
# │   └── ...
# ├── engine.py
# ├── main.py
# ├── requirements.txt
# └── README.md
# ```
#
# In these python files, you will be implementing the missing code blocks. These blocks are highlited by the TODOs
# ```#### TODO CSE527 STUDENT CODE STARTS HERE ######```
#
#
# In total there are 5 sections the code has to be filled. They are located in the files: coco.py, detr.py, matcher.py.
#
# To complete this part you are very much encouraged to:
# - understand how dataset, data sampler, dataloader, model, loss, & optimizer work together during training
# - refer to the actual DETR implementation at [git:facebookresearch/detr](https://github.com/facebookresearch/detr/tree/main) to get an idea of the training pipeline.
# - try to understand flow of control from main.py.
#
# You cannot complete the missing code blocks just from the given description in this ipynb, so you must read the code around. That is, you will read the inputs, outputs and how the inputs to the code block are created and how the outputs from the code block will be utilized.
#
# ## Task
# You should modify the DETR to output centroids rather than bounding boxes.
# Dataset:
# At the dataset level, you are not actually given the centroids, so you will use the instance segmentation masks to estimage the centroid for each object in annotation.
#
# Model:
# For this you will need to replace the classification and regression heads (already removed in the code provided to you, you just need to add new).
#
#
#
# ### 1 - coco.py: ConvertCocoPolysToMask.\__call__()  [20 points]
# Here you will be writing the logic to convert annotations to centroids in the following method.
# Note: You will have to figure out the inputs and outputs by yourself.
# ```
# def convert_coco_poly_to_centroids(segmentations, h, w, boxes) -> Torch.Tensor(shape = num_segmentations x 2)
# ```
#
# This method is part of data loader, and is called when generating the <sample, prediction> pairs, which will eventually be passed onto model for training.
#
# The _centroid_ we are referring to is a hypothetical point on the center of the object's main body part. It should ideally never be a point outside the annotation mask, and is likley always in the middle of body. Here in our case centroid should lie on the middle of horse's torso.
#
# steps:
#  - convert segmentations into masks [5 points]
#  - figure out a way to remove thin sections of object (legs and tail of the horse) from the mask, so only the largest body part (torso) will influence the centroid [10 points]
#  - compute the center of mass of the mask [5 point]
#
#  Feel free to pass on more inputs/outputs to the above method to support your way of computing centroids.
#
#
# ### 2 & 3 - detr.py: DETR.\__init__(), DETR.forward() [10 points]
#
# This is the DETR model architectrure. Here you will change the classification and regression heads, so the model can output centroids (unlike bboxes in original implementation).
# Also you will write logic to freeze the remaining section of DETR.
#
# Original model takes 300 hours to completely train from scrtch, so it is important to freeze all weights except necessary ones (heads).
#
# ### 4 - matcher.py: HungarianMatcher.forward() [15 points]
#
# Matcher is a key part of detection models. Refer to the paper or original DETR implementation to see how/why matcher is used. In this implementation we use Hungarian algorithm to align predictions to the ground truths.
#
# Breif:
# All object instance predictions are matched against the ground truth objects. This is necessary to compute the loss.
# Basically matcher will guess which ground truth object each prediction might be referring based on the closeness of predicted centroids and ground truth centroids.
#
# 100 centroid predictions will be matched against the ground truth centroids. You will compute a cost matrix that encdes the relation of prediction to GT.
#
# Refer: https://en.wikipedia.org/wiki/Hungarian_algorithm
#
# How you compute the cost matrix is again upto you.
#
# ### 5 - detr.py: SetCriterion.loss_centroid() [10 points]
#
# Here you will implement the loss function. Given the predicted centroids and ground truth centroids (which you processed in coco.py), you will write logic to compute variable _centroid_loss_
#
# The loss method is up to you.
#
# Note: At code blocks 4 & 5, make sure the loss/cost is in the normalized range only. I.e., loss/cost is calculated on normalized inputs.

# %% [markdown]
# ## Computing centroid
# ---
#
# Below block provide you a sandbox environment to play around and create a centroid finding algorithm. You will eventually use this code at detr/dataset/coco.py to complete the traning pipeline.
#
# Try to produce centroids that are within 10 pixels a far from the provided gt centroids.

# %%
import torch
from pycocotools import mask as mask_utils
from pycocotools.coco import COCO
from scipy.ndimage import binary_erosion, center_of_mass , label
import requests
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from pycocotools import mask as coco_mask
import numpy as np
from skimage import morphology, measure
import cv2
from scipy import ndimage

def convert_coco_poly_to_mask(segmentations, height, width):
    masks = []
    for polygons in segmentations:
        rles = coco_mask.frPyObjects(polygons, height, width)
        mask = coco_mask.decode(rles)
        if len(mask.shape) < 3:
            mask = mask[..., None]
        mask = torch.as_tensor(mask, dtype=torch.uint8)
        mask = mask.any(dim=2)
        masks.append(mask)
    if masks:
        masks = torch.stack(masks, dim=0)
    else:
        masks = torch.zeros((0, height, width), dtype=torch.uint8)
    return masks

def convert_coco_poly_to_centroids(segmentations, height, width, bboxes):
    centroids = []
    masks = convert_coco_poly_to_mask(segmentations, height, width)
    for i in range(0,len(masks)):
      mask_1= np.array(masks[i])
      mask_1= ndimage.binary_erosion(mask_1).astype(mask_1.dtype)
      val = np.argwhere(mask_1 == 1)
      if len(val) > 0:
        centroid = np.mean(val, axis=0)
        centroids.append([centroid[1], centroid[0]])
    centroids= torch.tensor(centroids, dtype=torch.float32)

    return centroids

# %%
def estimate_centroids(img, anns):
    h, w = img['height'], img['width']
    # Get segmentations and convert them to centroids
    segmentations = [ann['segmentation'] for ann in anns]
    boxes = [obj["bbox"] for obj in anns]
    boxes = torch.as_tensor(boxes, dtype=torch.float32).reshape(-1, 4)
    boxes[:, 2:] += boxes[:, :2]
    boxes[:, 0::2].clamp_(min=0, max=w)
    boxes[:, 1::2].clamp_(min=0, max=h)
    return convert_coco_poly_to_centroids(segmentations, h, w, boxes)


def compute_drift_rate(centroids, gt_centroids, gt_areas):
  distance_matrix = torch.cdist(centroids, gt_centroids)
  distances = []
  equivalent_lengths = []
  for i in range(len(centroids)):
      min_distance = torch.min(distance_matrix[i])
      min_distance_index = torch.argmin(distance_matrix[i])
      distances.append(min_distance)
      equivalent_lengths.append(np.sqrt(gt_areas[min_distance_index]))
  return torch.div(torch.Tensor(distances), torch.Tensor(equivalent_lengths))


# driver code
img_id = 144505
img = coco.loadImgs(img_id)[0]
img_data = Image.open(requests.get(img['coco_url'], stream=True).raw)

# Get image annotations
anns = coco.loadAnns(coco.getAnnIds(img_id))
centroids = estimate_centroids(img, anns)
gt_centroids = torch.Tensor([[378, 298],[537, 258]])
print(f'Actual Centroids:{gt_centroids}')
print(f'Predicted centroids: {centroids}')
plt.imshow(img_data)
for centroid in centroids:
    plt.plot(centroid[0], centroid[1], 'ro')
for centroid in gt_centroids:
    plt.plot(centroid[0], centroid[1], 'bo')
# Show image
plt.title(f'Drift dist = {compute_drift_rate(centroids, gt_centroids, [ann["area"] for ann in anns])}')
plt.show()
# Out:
# Actual Centroids:tensor([[378., 298.],
#         [537., 258.]])
# Predicted centroids: tensor([[379.2493, 324.2499],
#         [536.4308, 264.7174]])

# %% [markdown]
# ## Training
# ---
#
# Implement all five mentioned code blocks and use the below command AS IS. You can change BS, num_epochs, num_workers. (use this output training  [log](https://drive.google.com/file/d/1ZGd-ciOKkajri0GEOwc-uJDBjGJHJdNY/view?usp=drive_link) for your reference).
#
# Make sure checkpoints are being saved correctly and sometime not mistakenly being overriden due to multiple executions.
#
# You can use the validation loss/loss_centroid  as a metric to track performance.
#
# For grading:
# - There are no strict limits on evaluation metrics.
# - In the last cell of this notebook _avg_drift_rate_ metric is computed on a subset of validation ds. Try to score below 0.35.

# %%
# !python -u main.py --coco_path $PATH_TO_COCO --batch_size 10 --num_workers 12 --epochs 20 --output_dir './checkpoints'  --resume https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth --freeze_body
# Out:
# Not using distributed mode
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=10, weight_decay=0.0001, epochs=20, lr_drop=200, clip_max_norm=0.1, frozen_weights=None, freeze_body=True, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_centroid=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, cent_loss_coef=5, giou_loss_coef=2, eos_coef=0.1, dataset_file='coco', coco_path='/gdrive/MyDrive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', coco_panoptic_path=None, remove_difficult=False, output_dir='./checkpoints', device='cuda', seed=42, resume='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth', start_epoch=0, eval=False, num_workers=12, world_size=1, dist_url='env://', distributed=False)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 683013
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# deleted some params ['bbox_embed.layers.0.weight', 'bbox_embed.layers.0.bias', 'bbox_embed.layers.1.weight', 'bbox_embed.layers.1.bias', 'bbox_embed.layers.2.weight', 'bbox_embed.layers.2.bias']
# Start training
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [0]  [ 0/50]  eta: 0:07:20  lr: 0.000100  class_error: 0.00  loss: 13.7439 (13.7439)  loss_ce: 1.3030 (1.3030)  loss_centroid: 0.9715 (0.9715)  loss_ce_0: 1.3789 (1.3789)  loss_centroid_0: 1.0124 (1.0124)  loss_ce_1: 1.2845 (1.2845)  loss_centroid_1: 1.0018 (1.0018)  loss_ce_2: 1.2905 (1.2905)  loss_centroid_2: 0.9825 (0.9825)  loss_ce_3: 1.2778 (1.2778)  loss_centroid_3: 0.9822 (0.9822)  loss_ce_4: 1.2818 (1.2818)  loss_centroid_4: 0.9771 (0.9771)  loss_ce_unscaled: 1.3030 (1.3030)  class_error_unscaled: 0.0000 (0.0000)  cardinality_error_unscaled: 94.8000 (94.8000)  loss_centroid_unscaled: 0.1943 (0.1943)  loss_ce_0_unscaled: 1.3789 (1.3789)  cardinality_error_0_unscaled: 96.5000 (96.5000)  loss_centroid_0_unscaled: 0.2025 (0.2025)  loss_ce_1_unscaled: 1.2845 (1.2845)  cardinality_error_1_unscaled: 94.8000 (94.8000)  loss_centroid_1_unscaled: 0.2004 (0.2004)  loss_ce_2_unscaled: 1.2905 (1.2905)  cardinality_error_2_unscaled: 94.4000 (94.4000)  loss_centroid_2_unscaled: 0.1965 (0.1965)  loss_ce_3_unscaled: 1.2778 (1.2778)  cardinality_error_3_unscaled: 94.6000 (94.6000)  loss_centroid_3_unscaled: 0.1964 (0.1964)  loss_ce_4_unscaled: 1.2818 (1.2818)  cardinality_error_4_unscaled: 94.0000 (94.0000)  loss_centroid_4_unscaled: 0.1954 (0.1954)  time: 8.8048  data: 5.2787  max mem: 1688
# Epoch: [0]  [10/50]  eta: 0:00:50  lr: 0.000100  class_error: 7.14  loss: 14.4741 (14.5065)  loss_ce: 1.1649 (1.1735)  loss_centroid: 1.3080 (1.2446)  loss_ce_0: 1.2362 (1.2532)  loss_centroid_0: 1.2782 (1.2310)  loss_ce_1: 1.1526 (1.1650)  loss_centroid_1: 1.2905 (1.2360)  loss_ce_2: 1.1492 (1.1675)  loss_centroid_2: 1.2872 (1.2390)  loss_ce_3: 1.1428 (1.1498)  loss_centroid_3: 1.2810 (1.2459)  loss_ce_4: 1.1435 (1.1571)  loss_centroid_4: 1.3002 (1.2438)  loss_ce_unscaled: 1.1649 (1.1735)  class_error_unscaled: 0.0000 (1.4069)  cardinality_error_unscaled: 89.9000 (89.4909)  loss_centroid_unscaled: 0.2616 (0.2489)  loss_ce_0_unscaled: 1.2362 (1.2532)  cardinality_error_0_unscaled: 93.4000 (93.2273)  loss_centroid_0_unscaled: 0.2556 (0.2462)  loss_ce_1_unscaled: 1.1526 (1.1650)  cardinality_error_1_unscaled: 90.4000 (89.8818)  loss_centroid_1_unscaled: 0.2581 (0.2472)  loss_ce_2_unscaled: 1.1492 (1.1675)  cardinality_error_2_unscaled: 89.2000 (89.0455)  loss_centroid_2_unscaled: 0.2574 (0.2478)  loss_ce_3_unscaled: 1.1428 (1.1498)  cardinality_error_3_unscaled: 86.9000 (86.9727)  loss_centroid_3_unscaled: 0.2562 (0.2492)  loss_ce_4_unscaled: 1.1435 (1.1571)  cardinality_error_4_unscaled: 87.8000 (87.4091)  loss_centroid_4_unscaled: 0.2600 (0.2488)  time: 1.2693  data: 0.5534  max mem: 1698
# Epoch: [0]  [20/50]  eta: 0:00:28  lr: 0.000100  class_error: 16.67  loss: 14.2838 (14.3389)  loss_ce: 1.0867 (1.1183)  loss_centroid: 1.3080 (1.2747)  loss_ce_0: 1.1632 (1.1983)  loss_centroid_0: 1.2782 (1.2534)  loss_ce_1: 1.0834 (1.1099)  loss_centroid_1: 1.2905 (1.2592)  loss_ce_2: 1.0925 (1.1160)  loss_centroid_2: 1.2872 (1.2655)  loss_ce_3: 1.0685 (1.0975)  loss_centroid_3: 1.2810 (1.2693)  loss_ce_4: 1.0758 (1.1036)  loss_centroid_4: 1.3002 (1.2731)  loss_ce_unscaled: 1.0867 (1.1183)  class_error_unscaled: 5.0000 (6.8110)  cardinality_error_unscaled: 84.5000 (83.6571)  loss_centroid_unscaled: 0.2616 (0.2549)  loss_ce_0_unscaled: 1.1632 (1.1983)  cardinality_error_0_unscaled: 90.6000 (90.5238)  loss_centroid_0_unscaled: 0.2556 (0.2507)  loss_ce_1_unscaled: 1.0834 (1.1099)  cardinality_error_1_unscaled: 85.4000 (84.4619)  loss_centroid_1_unscaled: 0.2581 (0.2518)  loss_ce_2_unscaled: 1.0925 (1.1160)  cardinality_error_2_unscaled: 84.4000 (83.4476)  loss_centroid_2_unscaled: 0.2574 (0.2531)  loss_ce_3_unscaled: 1.0685 (1.0975)  cardinality_error_3_unscaled: 81.6000 (79.9810)  loss_centroid_3_unscaled: 0.2562 (0.2539)  loss_ce_4_unscaled: 1.0758 (1.1036)  cardinality_error_4_unscaled: 82.9000 (80.6524)  loss_centroid_4_unscaled: 0.2600 (0.2546)  time: 0.9632  data: 0.3491  max mem: 1698
# Epoch: [0]  [30/50]  eta: 0:00:16  lr: 0.000100  class_error: 42.11  loss: 13.4835 (13.2812)  loss_ce: 1.0330 (1.0541)  loss_centroid: 1.0716 (1.1623)  loss_ce_0: 1.1295 (1.1381)  loss_centroid_0: 1.0414 (1.1392)  loss_ce_1: 1.0223 (1.0480)  loss_centroid_1: 1.0595 (1.1434)  loss_ce_2: 1.0443 (1.0520)  loss_centroid_2: 1.0791 (1.1526)  loss_ce_3: 1.0279 (1.0336)  loss_centroid_3: 1.0558 (1.1557)  loss_ce_4: 1.0239 (1.0396)  loss_centroid_4: 1.0643 (1.1625)  loss_ce_unscaled: 1.0330 (1.0541)  class_error_unscaled: 8.3333 (12.6939)  cardinality_error_unscaled: 77.2000 (74.1710)  loss_centroid_unscaled: 0.2143 (0.2325)  loss_ce_0_unscaled: 1.1295 (1.1381)  cardinality_error_0_unscaled: 87.5000 (84.8226)  loss_centroid_0_unscaled: 0.2083 (0.2278)  loss_ce_1_unscaled: 1.0223 (1.0480)  cardinality_error_1_unscaled: 77.0000 (75.1226)  loss_centroid_1_unscaled: 0.2119 (0.2287)  loss_ce_2_unscaled: 1.0443 (1.0520)  cardinality_error_2_unscaled: 77.6000 (73.7935)  loss_centroid_2_unscaled: 0.2158 (0.2305)  loss_ce_3_unscaled: 1.0279 (1.0336)  cardinality_error_3_unscaled: 71.2000 (69.5613)  loss_centroid_3_unscaled: 0.2112 (0.2311)  loss_ce_4_unscaled: 1.0239 (1.0396)  cardinality_error_4_unscaled: 72.5000 (70.3387)  loss_centroid_4_unscaled: 0.2129 (0.2325)  time: 0.8069  data: 0.2553  max mem: 1698
# Epoch: [0]  [40/50]  eta: 0:00:07  lr: 0.000100  class_error: 64.71  loss: 12.1603 (12.3453)  loss_ce: 0.9788 (0.9996)  loss_centroid: 1.0281 (1.0595)  loss_ce_0: 1.0632 (1.0842)  loss_centroid_0: 1.0022 (1.0375)  loss_ce_1: 0.9693 (0.9963)  loss_centroid_1: 1.0018 (1.0386)  loss_ce_2: 0.9704 (0.9990)  loss_centroid_2: 1.0118 (1.0506)  loss_ce_3: 0.9576 (0.9808)  loss_centroid_3: 1.0209 (1.0525)  loss_ce_4: 0.9660 (0.9867)  loss_centroid_4: 1.0337 (1.0598)  loss_ce_unscaled: 0.9788 (0.9996)  class_error_unscaled: 14.8148 (22.2922)  cardinality_error_unscaled: 69.8000 (63.7732)  loss_centroid_unscaled: 0.2056 (0.2119)  loss_ce_0_unscaled: 1.0632 (1.0842)  cardinality_error_0_unscaled: 82.0000 (76.5366)  loss_centroid_0_unscaled: 0.2004 (0.2075)  loss_ce_1_unscaled: 0.9693 (0.9963)  cardinality_error_1_unscaled: 72.7000 (64.6341)  loss_centroid_1_unscaled: 0.2004 (0.2077)  loss_ce_2_unscaled: 0.9704 (0.9990)  cardinality_error_2_unscaled: 69.9000 (63.3585)  loss_centroid_2_unscaled: 0.2024 (0.2101)  loss_ce_3_unscaled: 0.9576 (0.9808)  cardinality_error_3_unscaled: 64.3000 (58.9000)  loss_centroid_3_unscaled: 0.2042 (0.2105)  loss_ce_4_unscaled: 0.9660 (0.9867)  cardinality_error_4_unscaled: 65.8000 (59.5415)  loss_centroid_4_unscaled: 0.2067 (0.2120)  time: 0.7146  data: 0.2013  max mem: 1698
# Epoch: [0]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 95.00  loss: 11.2909 (11.6277)  loss_ce: 0.9312 (0.9526)  loss_centroid: 0.9309 (0.9854)  loss_ce_0: 1.0352 (1.0371)  loss_centroid_0: 0.9237 (0.9649)  loss_ce_1: 0.9220 (0.9517)  loss_centroid_1: 0.9185 (0.9650)  loss_ce_2: 0.9167 (0.9527)  loss_centroid_2: 0.9320 (0.9778)  loss_ce_3: 0.9158 (0.9344)  loss_centroid_3: 0.9338 (0.9799)  loss_ce_4: 0.9161 (0.9409)  loss_centroid_4: 0.9319 (0.9855)  loss_ce_unscaled: 0.9312 (0.9526)  class_error_unscaled: 24.1379 (32.8367)  cardinality_error_unscaled: 58.6000 (54.5180)  loss_centroid_unscaled: 0.1862 (0.1971)  loss_ce_0_unscaled: 1.0352 (1.0371)  cardinality_error_0_unscaled: 76.7000 (67.8040)  loss_centroid_0_unscaled: 0.1847 (0.1930)  loss_ce_1_unscaled: 0.9220 (0.9517)  cardinality_error_1_unscaled: 58.9000 (55.4060)  loss_centroid_1_unscaled: 0.1837 (0.1930)  loss_ce_2_unscaled: 0.9167 (0.9527)  cardinality_error_2_unscaled: 57.5000 (54.3680)  loss_centroid_2_unscaled: 0.1864 (0.1956)  loss_ce_3_unscaled: 0.9158 (0.9344)  cardinality_error_3_unscaled: 51.0000 (49.9900)  loss_centroid_3_unscaled: 0.1868 (0.1960)  loss_ce_4_unscaled: 0.9161 (0.9409)  cardinality_error_4_unscaled: 53.0000 (50.5240)  loss_centroid_4_unscaled: 0.1864 (0.1971)  time: 0.6679  data: 0.1736  max mem: 1698
# Epoch: [0] Total time: 0:00:33 (0.6756 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:28  class_error: 64.52  loss: 12.9302 (12.9302)  loss_ce: 0.7708 (0.7708)  loss_centroid: 1.3845 (1.3845)  loss_ce_0: 0.8742 (0.8742)  loss_centroid_0: 1.3354 (1.3354)  loss_ce_1: 0.7757 (0.7757)  loss_centroid_1: 1.3549 (1.3549)  loss_ce_2: 0.7698 (0.7698)  loss_centroid_2: 1.3561 (1.3561)  loss_ce_3: 0.7713 (0.7713)  loss_centroid_3: 1.3830 (1.3830)  loss_ce_4: 0.7703 (0.7703)  loss_centroid_4: 1.3843 (1.3843)  loss_ce_unscaled: 0.7708 (0.7708)  class_error_unscaled: 64.5161 (64.5161)  cardinality_error_unscaled: 13.0000 (13.0000)  loss_centroid_unscaled: 0.2769 (0.2769)  loss_ce_0_unscaled: 0.8742 (0.8742)  cardinality_error_0_unscaled: 22.0000 (22.0000)  loss_centroid_0_unscaled: 0.2671 (0.2671)  loss_ce_1_unscaled: 0.7757 (0.7757)  cardinality_error_1_unscaled: 8.3000 (8.3000)  loss_centroid_1_unscaled: 0.2710 (0.2710)  loss_ce_2_unscaled: 0.7698 (0.7698)  cardinality_error_2_unscaled: 12.9000 (12.9000)  loss_centroid_2_unscaled: 0.2712 (0.2712)  loss_ce_3_unscaled: 0.7713 (0.7713)  cardinality_error_3_unscaled: 8.9000 (8.9000)  loss_centroid_3_unscaled: 0.2766 (0.2766)  loss_ce_4_unscaled: 0.7703 (0.7703)  cardinality_error_4_unscaled: 10.9000 (10.9000)  loss_centroid_4_unscaled: 0.2769 (0.2769)  time: 5.6939  data: 4.7258  max mem: 3090
# Test:  [4/5]  eta: 0:00:02  class_error: 59.09  loss: 12.1341 (12.1098)  loss_ce: 0.7114 (0.7148)  loss_centroid: 1.2893 (1.2974)  loss_ce_0: 0.8110 (0.8127)  loss_centroid_0: 1.2869 (1.2729)  loss_ce_1: 0.7197 (0.7235)  loss_centroid_1: 1.2842 (1.2804)  loss_ce_2: 0.7151 (0.7147)  loss_centroid_2: 1.2911 (1.2893)  loss_ce_3: 0.7023 (0.7077)  loss_centroid_3: 1.2886 (1.2925)  loss_ce_4: 0.7076 (0.7107)  loss_centroid_4: 1.2794 (1.2932)  loss_ce_unscaled: 0.7114 (0.7148)  class_error_unscaled: 59.0909 (62.5811)  cardinality_error_unscaled: 12.7000 (11.2400)  loss_centroid_unscaled: 0.2579 (0.2595)  loss_ce_0_unscaled: 0.8110 (0.8127)  cardinality_error_0_unscaled: 20.6000 (19.6800)  loss_centroid_0_unscaled: 0.2574 (0.2546)  loss_ce_1_unscaled: 0.7197 (0.7235)  cardinality_error_1_unscaled: 8.3000 (8.3000)  loss_centroid_1_unscaled: 0.2568 (0.2561)  loss_ce_2_unscaled: 0.7151 (0.7147)  cardinality_error_2_unscaled: 12.9000 (11.5400)  loss_centroid_2_unscaled: 0.2582 (0.2579)  loss_ce_3_unscaled: 0.7023 (0.7077)  cardinality_error_3_unscaled: 8.9000 (8.4200)  loss_centroid_3_unscaled: 0.2577 (0.2585)  loss_ce_4_unscaled: 0.7076 (0.7107)  cardinality_error_4_unscaled: 9.8000 (8.9200)  loss_centroid_4_unscaled: 0.2559 (0.2586)  time: 2.2261  data: 0.9713  max mem: 4861
# Test: Total time: 0:00:11 (2.2647 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [1]  [ 0/50]  eta: 0:04:51  lr: 0.000100  class_error: 92.31  loss: 7.6959 (7.6959)  loss_ce: 0.6513 (0.6513)  loss_centroid: 0.6186 (0.6186)  loss_ce_0: 0.7568 (0.7568)  loss_centroid_0: 0.6394 (0.6394)  loss_ce_1: 0.6759 (0.6759)  loss_centroid_1: 0.5915 (0.5915)  loss_ce_2: 0.6591 (0.6591)  loss_centroid_2: 0.6006 (0.6006)  loss_ce_3: 0.6423 (0.6423)  loss_centroid_3: 0.6130 (0.6130)  loss_ce_4: 0.6419 (0.6419)  loss_centroid_4: 0.6057 (0.6057)  loss_ce_unscaled: 0.6513 (0.6513)  class_error_unscaled: 92.3077 (92.3077)  cardinality_error_unscaled: 6.0000 (6.0000)  loss_centroid_unscaled: 0.1237 (0.1237)  loss_ce_0_unscaled: 0.7568 (0.7568)  cardinality_error_0_unscaled: 16.3000 (16.3000)  loss_centroid_0_unscaled: 0.1279 (0.1279)  loss_ce_1_unscaled: 0.6759 (0.6759)  cardinality_error_1_unscaled: 4.6000 (4.6000)  loss_centroid_1_unscaled: 0.1183 (0.1183)  loss_ce_2_unscaled: 0.6591 (0.6591)  cardinality_error_2_unscaled: 5.6000 (5.6000)  loss_centroid_2_unscaled: 0.1201 (0.1201)  loss_ce_3_unscaled: 0.6423 (0.6423)  cardinality_error_3_unscaled: 4.0000 (4.0000)  loss_centroid_3_unscaled: 0.1226 (0.1226)  loss_ce_4_unscaled: 0.6419 (0.6419)  cardinality_error_4_unscaled: 4.2000 (4.2000)  loss_centroid_4_unscaled: 0.1211 (0.1211)  time: 5.8390  data: 3.4074  max mem: 4861
# Epoch: [1]  [10/50]  eta: 0:00:49  lr: 0.000100  class_error: 88.89  loss: 7.1282 (7.0810)  loss_ce: 0.6743 (0.6749)  loss_centroid: 0.5024 (0.4994)  loss_ce_0: 0.7683 (0.7696)  loss_centroid_0: 0.4747 (0.4713)  loss_ce_1: 0.6764 (0.6936)  loss_centroid_1: 0.4554 (0.4693)  loss_ce_2: 0.6693 (0.6786)  loss_centroid_2: 0.4979 (0.4946)  loss_ce_3: 0.6595 (0.6689)  loss_centroid_3: 0.4841 (0.4922)  loss_ce_4: 0.6662 (0.6726)  loss_centroid_4: 0.4844 (0.4962)  loss_ce_unscaled: 0.6743 (0.6749)  class_error_unscaled: 90.4762 (88.9080)  cardinality_error_unscaled: 3.9000 (4.9818)  loss_centroid_unscaled: 0.1005 (0.0999)  loss_ce_0_unscaled: 0.7683 (0.7696)  cardinality_error_0_unscaled: 13.8000 (13.2000)  loss_centroid_0_unscaled: 0.0949 (0.0943)  loss_ce_1_unscaled: 0.6764 (0.6936)  cardinality_error_1_unscaled: 3.1000 (3.9273)  loss_centroid_1_unscaled: 0.0911 (0.0939)  loss_ce_2_unscaled: 0.6693 (0.6786)  cardinality_error_2_unscaled: 4.0000 (4.7364)  loss_centroid_2_unscaled: 0.0996 (0.0989)  loss_ce_3_unscaled: 0.6595 (0.6689)  cardinality_error_3_unscaled: 3.6000 (3.8818)  loss_centroid_3_unscaled: 0.0968 (0.0984)  loss_ce_4_unscaled: 0.6662 (0.6726)  cardinality_error_4_unscaled: 3.5000 (3.8636)  loss_centroid_4_unscaled: 0.0969 (0.0992)  time: 1.2483  data: 0.5148  max mem: 4861
# Epoch: [1]  [20/50]  eta: 0:00:26  lr: 0.000100  class_error: 100.00  loss: 6.7607 (6.5990)  loss_ce: 0.6527 (0.6505)  loss_centroid: 0.4408 (0.4399)  loss_ce_0: 0.7437 (0.7392)  loss_centroid_0: 0.4501 (0.4147)  loss_ce_1: 0.6693 (0.6675)  loss_centroid_1: 0.4197 (0.4194)  loss_ce_2: 0.6591 (0.6558)  loss_centroid_2: 0.4581 (0.4390)  loss_ce_3: 0.6423 (0.6437)  loss_centroid_3: 0.4421 (0.4413)  loss_ce_4: 0.6499 (0.6477)  loss_centroid_4: 0.4409 (0.4402)  loss_ce_unscaled: 0.6527 (0.6505)  class_error_unscaled: 95.4545 (92.1283)  cardinality_error_unscaled: 3.4000 (3.7476)  loss_centroid_unscaled: 0.0882 (0.0880)  loss_ce_0_unscaled: 0.7437 (0.7392)  cardinality_error_0_unscaled: 8.2000 (8.8905)  loss_centroid_0_unscaled: 0.0900 (0.0829)  loss_ce_1_unscaled: 0.6693 (0.6675)  cardinality_error_1_unscaled: 2.7000 (3.0810)  loss_centroid_1_unscaled: 0.0839 (0.0839)  loss_ce_2_unscaled: 0.6591 (0.6558)  cardinality_error_2_unscaled: 3.3000 (3.6333)  loss_centroid_2_unscaled: 0.0916 (0.0878)  loss_ce_3_unscaled: 0.6423 (0.6437)  cardinality_error_3_unscaled: 2.6000 (3.0810)  loss_centroid_3_unscaled: 0.0884 (0.0883)  loss_ce_4_unscaled: 0.6499 (0.6477)  cardinality_error_4_unscaled: 2.9000 (3.0571)  loss_centroid_4_unscaled: 0.0882 (0.0880)  time: 0.8771  data: 0.3000  max mem: 4861
# Epoch: [1]  [30/50]  eta: 0:00:14  lr: 0.000100  class_error: 100.00  loss: 5.8724 (6.1575)  loss_ce: 0.6072 (0.6242)  loss_centroid: 0.3816 (0.3905)  loss_ce_0: 0.6936 (0.7081)  loss_centroid_0: 0.3695 (0.3725)  loss_ce_1: 0.6307 (0.6399)  loss_centroid_1: 0.3487 (0.3759)  loss_ce_2: 0.6108 (0.6297)  loss_centroid_2: 0.3592 (0.3916)  loss_ce_3: 0.5966 (0.6178)  loss_centroid_3: 0.3896 (0.3941)  loss_ce_4: 0.5969 (0.6210)  loss_centroid_4: 0.3899 (0.3922)  loss_ce_unscaled: 0.6072 (0.6242)  class_error_unscaled: 97.8261 (94.3526)  cardinality_error_unscaled: 2.8000 (3.1516)  loss_centroid_unscaled: 0.0763 (0.0781)  loss_ce_0_unscaled: 0.6936 (0.7081)  cardinality_error_0_unscaled: 3.8000 (6.5903)  loss_centroid_0_unscaled: 0.0739 (0.0745)  loss_ce_1_unscaled: 0.6307 (0.6399)  cardinality_error_1_unscaled: 1.9000 (2.6613)  loss_centroid_1_unscaled: 0.0697 (0.0752)  loss_ce_2_unscaled: 0.6108 (0.6297)  cardinality_error_2_unscaled: 2.4000 (3.0710)  loss_centroid_2_unscaled: 0.0718 (0.0783)  loss_ce_3_unscaled: 0.5966 (0.6178)  cardinality_error_3_unscaled: 1.8000 (2.6581)  loss_centroid_3_unscaled: 0.0779 (0.0788)  loss_ce_4_unscaled: 0.5969 (0.6210)  cardinality_error_4_unscaled: 2.1000 (2.6613)  loss_centroid_4_unscaled: 0.0780 (0.0784)  time: 0.7462  data: 0.2227  max mem: 4861
# Epoch: [1]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 100.00  loss: 5.3673 (5.9222)  loss_ce: 0.5925 (0.6114)  loss_centroid: 0.3245 (0.3651)  loss_ce_0: 0.6744 (0.6888)  loss_centroid_0: 0.3081 (0.3499)  loss_ce_1: 0.6061 (0.6250)  loss_centroid_1: 0.3156 (0.3525)  loss_ce_2: 0.5952 (0.6157)  loss_centroid_2: 0.3135 (0.3659)  loss_ce_3: 0.5818 (0.6050)  loss_centroid_3: 0.3446 (0.3680)  loss_ce_4: 0.5878 (0.6088)  loss_centroid_4: 0.3392 (0.3662)  loss_ce_unscaled: 0.5925 (0.6114)  class_error_unscaled: 100.0000 (95.6192)  cardinality_error_unscaled: 2.2000 (2.9049)  loss_centroid_unscaled: 0.0649 (0.0730)  loss_ce_0_unscaled: 0.6744 (0.6888)  cardinality_error_0_unscaled: 2.5000 (5.3829)  loss_centroid_0_unscaled: 0.0616 (0.0700)  loss_ce_1_unscaled: 0.6061 (0.6250)  cardinality_error_1_unscaled: 2.0000 (2.5122)  loss_centroid_1_unscaled: 0.0631 (0.0705)  loss_ce_2_unscaled: 0.5952 (0.6157)  cardinality_error_2_unscaled: 2.2000 (2.8049)  loss_centroid_2_unscaled: 0.0627 (0.0732)  loss_ce_3_unscaled: 0.5818 (0.6050)  cardinality_error_3_unscaled: 2.0000 (2.5268)  loss_centroid_3_unscaled: 0.0689 (0.0736)  loss_ce_4_unscaled: 0.5878 (0.6088)  cardinality_error_4_unscaled: 2.1000 (2.5268)  loss_centroid_4_unscaled: 0.0678 (0.0732)  time: 0.6791  data: 0.1826  max mem: 4861
# Epoch: [1]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 5.3358 (5.8176)  loss_ce: 0.5822 (0.6022)  loss_centroid: 0.3048 (0.3568)  loss_ce_0: 0.6503 (0.6752)  loss_centroid_0: 0.2927 (0.3442)  loss_ce_1: 0.5911 (0.6147)  loss_centroid_1: 0.3004 (0.3463)  loss_ce_2: 0.5925 (0.6064)  loss_centroid_2: 0.2969 (0.3571)  loss_ce_3: 0.5785 (0.5972)  loss_centroid_3: 0.3032 (0.3590)  loss_ce_4: 0.5852 (0.6006)  loss_centroid_4: 0.3066 (0.3581)  loss_ce_unscaled: 0.5822 (0.6022)  class_error_unscaled: 100.0000 (96.4077)  cardinality_error_unscaled: 2.3000 (2.8160)  loss_centroid_unscaled: 0.0610 (0.0714)  loss_ce_0_unscaled: 0.6503 (0.6752)  cardinality_error_0_unscaled: 2.4000 (4.8180)  loss_centroid_0_unscaled: 0.0585 (0.0688)  loss_ce_1_unscaled: 0.5911 (0.6147)  cardinality_error_1_unscaled: 2.0000 (2.4900)  loss_centroid_1_unscaled: 0.0601 (0.0693)  loss_ce_2_unscaled: 0.5925 (0.6064)  cardinality_error_2_unscaled: 2.3000 (2.7340)  loss_centroid_2_unscaled: 0.0594 (0.0714)  loss_ce_3_unscaled: 0.5785 (0.5972)  cardinality_error_3_unscaled: 2.1000 (2.5040)  loss_centroid_3_unscaled: 0.0606 (0.0718)  loss_ce_4_unscaled: 0.5852 (0.6006)  cardinality_error_4_unscaled: 2.1000 (2.5040)  loss_centroid_4_unscaled: 0.0613 (0.0716)  time: 0.6328  data: 0.1537  max mem: 4861
# Epoch: [1] Total time: 0:00:31 (0.6379 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:18  class_error: 100.00  loss: 10.7353 (10.7353)  loss_ce: 0.6129 (0.6129)  loss_centroid: 1.2175 (1.2175)  loss_ce_0: 0.6818 (0.6818)  loss_centroid_0: 1.0779 (1.0779)  loss_ce_1: 0.6322 (0.6322)  loss_centroid_1: 1.1153 (1.1153)  loss_ce_2: 0.6240 (0.6240)  loss_centroid_2: 1.1421 (1.1421)  loss_ce_3: 0.6216 (0.6216)  loss_centroid_3: 1.1910 (1.1910)  loss_ce_4: 0.6213 (0.6213)  loss_centroid_4: 1.1979 (1.1979)  loss_ce_unscaled: 0.6129 (0.6129)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.2435 (0.2435)  loss_ce_0_unscaled: 0.6818 (0.6818)  cardinality_error_0_unscaled: 3.0000 (3.0000)  loss_centroid_0_unscaled: 0.2156 (0.2156)  loss_ce_1_unscaled: 0.6322 (0.6322)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.2231 (0.2231)  loss_ce_2_unscaled: 0.6240 (0.6240)  cardinality_error_2_unscaled: 3.0000 (3.0000)  loss_centroid_2_unscaled: 0.2284 (0.2284)  loss_ce_3_unscaled: 0.6216 (0.6216)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.2382 (0.2382)  loss_ce_4_unscaled: 0.6213 (0.6213)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.2396 (0.2396)  time: 3.7825  data: 2.8319  max mem: 4861
# Test:  [4/5]  eta: 0:00:01  class_error: 100.00  loss: 7.4689 (8.0656)  loss_ce: 0.5090 (0.5240)  loss_centroid: 0.7483 (0.8284)  loss_ce_0: 0.5754 (0.5920)  loss_centroid_0: 0.6958 (0.7621)  loss_ce_1: 0.5335 (0.5473)  loss_centroid_1: 0.6802 (0.7700)  loss_ce_2: 0.5215 (0.5365)  loss_centroid_2: 0.7302 (0.8015)  loss_ce_3: 0.5205 (0.5307)  loss_centroid_3: 0.7544 (0.8190)  loss_ce_4: 0.5116 (0.5270)  loss_centroid_4: 0.7594 (0.8270)  loss_ce_unscaled: 0.5090 (0.5240)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.9000 (2.1200)  loss_centroid_unscaled: 0.1497 (0.1657)  loss_ce_0_unscaled: 0.5754 (0.5920)  cardinality_error_0_unscaled: 1.9000 (2.0000)  loss_centroid_0_unscaled: 0.1392 (0.1524)  loss_ce_1_unscaled: 0.5335 (0.5473)  cardinality_error_1_unscaled: 2.0000 (2.1200)  loss_centroid_1_unscaled: 0.1360 (0.1540)  loss_ce_2_unscaled: 0.5215 (0.5365)  cardinality_error_2_unscaled: 2.0000 (2.0800)  loss_centroid_2_unscaled: 0.1460 (0.1603)  loss_ce_3_unscaled: 0.5205 (0.5307)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.1509 (0.1638)  loss_ce_4_unscaled: 0.5116 (0.5270)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.1519 (0.1654)  time: 1.7913  data: 0.5966  max mem: 4861
# Test: Total time: 0:00:09 (1.8419 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [2]  [ 0/50]  eta: 0:07:06  lr: 0.000100  class_error: 100.00  loss: 4.6358 (4.6358)  loss_ce: 0.5310 (0.5310)  loss_centroid: 0.2326 (0.2326)  loss_ce_0: 0.5684 (0.5684)  loss_centroid_0: 0.2383 (0.2383)  loss_ce_1: 0.5364 (0.5364)  loss_centroid_1: 0.2229 (0.2229)  loss_ce_2: 0.5329 (0.5329)  loss_centroid_2: 0.2406 (0.2406)  loss_ce_3: 0.5319 (0.5319)  loss_centroid_3: 0.2230 (0.2230)  loss_ce_4: 0.5435 (0.5435)  loss_centroid_4: 0.2343 (0.2343)  loss_ce_unscaled: 0.5310 (0.5310)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.4000 (2.4000)  loss_centroid_unscaled: 0.0465 (0.0465)  loss_ce_0_unscaled: 0.5684 (0.5684)  cardinality_error_0_unscaled: 2.2000 (2.2000)  loss_centroid_0_unscaled: 0.0477 (0.0477)  loss_ce_1_unscaled: 0.5364 (0.5364)  cardinality_error_1_unscaled: 2.3000 (2.3000)  loss_centroid_1_unscaled: 0.0446 (0.0446)  loss_ce_2_unscaled: 0.5329 (0.5329)  cardinality_error_2_unscaled: 2.4000 (2.4000)  loss_centroid_2_unscaled: 0.0481 (0.0481)  loss_ce_3_unscaled: 0.5319 (0.5319)  cardinality_error_3_unscaled: 2.4000 (2.4000)  loss_centroid_3_unscaled: 0.0446 (0.0446)  loss_ce_4_unscaled: 0.5435 (0.5435)  cardinality_error_4_unscaled: 2.4000 (2.4000)  loss_centroid_4_unscaled: 0.0469 (0.0469)  time: 8.5275  data: 7.4620  max mem: 4861
# Epoch: [2]  [10/50]  eta: 0:00:49  lr: 0.000100  class_error: 100.00  loss: 4.7455 (4.9082)  loss_ce: 0.5310 (0.5214)  loss_centroid: 0.2868 (0.2947)  loss_ce_0: 0.5651 (0.5675)  loss_centroid_0: 0.2831 (0.2750)  loss_ce_1: 0.5250 (0.5228)  loss_centroid_1: 0.2665 (0.2873)  loss_ce_2: 0.5178 (0.5197)  loss_centroid_2: 0.2701 (0.2974)  loss_ce_3: 0.5319 (0.5223)  loss_centroid_3: 0.2809 (0.2867)  loss_ce_4: 0.5409 (0.5229)  loss_centroid_4: 0.2736 (0.2904)  loss_ce_unscaled: 0.5310 (0.5214)  class_error_unscaled: 100.0000 (99.6503)  cardinality_error_unscaled: 2.3000 (2.1636)  loss_centroid_unscaled: 0.0574 (0.0589)  loss_ce_0_unscaled: 0.5651 (0.5675)  cardinality_error_0_unscaled: 2.2000 (2.0909)  loss_centroid_0_unscaled: 0.0566 (0.0550)  loss_ce_1_unscaled: 0.5250 (0.5228)  cardinality_error_1_unscaled: 2.2000 (2.1545)  loss_centroid_1_unscaled: 0.0533 (0.0575)  loss_ce_2_unscaled: 0.5178 (0.5197)  cardinality_error_2_unscaled: 2.2000 (2.1364)  loss_centroid_2_unscaled: 0.0540 (0.0595)  loss_ce_3_unscaled: 0.5319 (0.5223)  cardinality_error_3_unscaled: 2.3000 (2.1636)  loss_centroid_3_unscaled: 0.0562 (0.0573)  loss_ce_4_unscaled: 0.5409 (0.5229)  cardinality_error_4_unscaled: 2.3000 (2.1636)  loss_centroid_4_unscaled: 0.0547 (0.0581)  time: 1.2351  data: 0.7374  max mem: 4861
# Epoch: [2]  [20/50]  eta: 0:00:27  lr: 0.000100  class_error: 100.00  loss: 4.8248 (4.8672)  loss_ce: 0.5245 (0.5136)  loss_centroid: 0.2877 (0.2962)  loss_ce_0: 0.5630 (0.5562)  loss_centroid_0: 0.2831 (0.2798)  loss_ce_1: 0.5178 (0.5168)  loss_centroid_1: 0.2711 (0.2903)  loss_ce_2: 0.5149 (0.5116)  loss_centroid_2: 0.2879 (0.2958)  loss_ce_3: 0.5117 (0.5124)  loss_centroid_3: 0.2829 (0.2883)  loss_ce_4: 0.5296 (0.5138)  loss_centroid_4: 0.2898 (0.2924)  loss_ce_unscaled: 0.5245 (0.5136)  class_error_unscaled: 100.0000 (99.8168)  cardinality_error_unscaled: 2.1000 (2.1333)  loss_centroid_unscaled: 0.0575 (0.0592)  loss_ce_0_unscaled: 0.5630 (0.5562)  cardinality_error_0_unscaled: 2.1000 (2.0714)  loss_centroid_0_unscaled: 0.0566 (0.0560)  loss_ce_1_unscaled: 0.5178 (0.5168)  cardinality_error_1_unscaled: 2.1000 (2.1143)  loss_centroid_1_unscaled: 0.0542 (0.0581)  loss_ce_2_unscaled: 0.5149 (0.5116)  cardinality_error_2_unscaled: 2.0000 (2.1048)  loss_centroid_2_unscaled: 0.0576 (0.0592)  loss_ce_3_unscaled: 0.5117 (0.5124)  cardinality_error_3_unscaled: 2.1000 (2.1190)  loss_centroid_3_unscaled: 0.0566 (0.0577)  loss_ce_4_unscaled: 0.5296 (0.5138)  cardinality_error_4_unscaled: 2.1000 (2.1238)  loss_centroid_4_unscaled: 0.0580 (0.0585)  time: 0.9007  data: 0.4293  max mem: 4861
# Epoch: [2]  [30/50]  eta: 0:00:15  lr: 0.000100  class_error: 100.00  loss: 4.7456 (4.8120)  loss_ce: 0.5231 (0.5195)  loss_centroid: 0.2743 (0.2830)  loss_ce_0: 0.5583 (0.5585)  loss_centroid_0: 0.2473 (0.2605)  loss_ce_1: 0.5178 (0.5231)  loss_centroid_1: 0.2595 (0.2732)  loss_ce_2: 0.5178 (0.5187)  loss_centroid_2: 0.2619 (0.2785)  loss_ce_3: 0.5303 (0.5203)  loss_centroid_3: 0.2626 (0.2772)  loss_ce_4: 0.5296 (0.5210)  loss_centroid_4: 0.2691 (0.2785)  loss_ce_unscaled: 0.5231 (0.5195)  class_error_unscaled: 100.0000 (99.8759)  cardinality_error_unscaled: 2.2000 (2.1968)  loss_centroid_unscaled: 0.0549 (0.0566)  loss_ce_0_unscaled: 0.5583 (0.5585)  cardinality_error_0_unscaled: 2.2000 (2.1548)  loss_centroid_0_unscaled: 0.0495 (0.0521)  loss_ce_1_unscaled: 0.5178 (0.5231)  cardinality_error_1_unscaled: 2.2000 (2.1871)  loss_centroid_1_unscaled: 0.0519 (0.0546)  loss_ce_2_unscaled: 0.5178 (0.5187)  cardinality_error_2_unscaled: 2.2000 (2.1774)  loss_centroid_2_unscaled: 0.0524 (0.0557)  loss_ce_3_unscaled: 0.5303 (0.5203)  cardinality_error_3_unscaled: 2.2000 (2.1871)  loss_centroid_3_unscaled: 0.0525 (0.0554)  loss_ce_4_unscaled: 0.5296 (0.5210)  cardinality_error_4_unscaled: 2.2000 (2.1935)  loss_centroid_4_unscaled: 0.0538 (0.0557)  time: 0.7842  data: 0.3225  max mem: 4861
# Epoch: [2]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 100.00  loss: 4.7679 (4.8638)  loss_ce: 0.5245 (0.5209)  loss_centroid: 0.2850 (0.2892)  loss_ce_0: 0.5583 (0.5579)  loss_centroid_0: 0.2475 (0.2697)  loss_ce_1: 0.5178 (0.5244)  loss_centroid_1: 0.2704 (0.2814)  loss_ce_2: 0.5224 (0.5214)  loss_centroid_2: 0.2701 (0.2846)  loss_ce_3: 0.5304 (0.5221)  loss_centroid_3: 0.2644 (0.2830)  loss_ce_4: 0.5329 (0.5220)  loss_centroid_4: 0.2776 (0.2872)  loss_ce_unscaled: 0.5245 (0.5209)  class_error_unscaled: 100.0000 (99.9062)  cardinality_error_unscaled: 2.2000 (2.2341)  loss_centroid_unscaled: 0.0570 (0.0578)  loss_ce_0_unscaled: 0.5583 (0.5579)  cardinality_error_0_unscaled: 2.2000 (2.1976)  loss_centroid_0_unscaled: 0.0495 (0.0539)  loss_ce_1_unscaled: 0.5178 (0.5244)  cardinality_error_1_unscaled: 2.2000 (2.2268)  loss_centroid_1_unscaled: 0.0541 (0.0563)  loss_ce_2_unscaled: 0.5224 (0.5214)  cardinality_error_2_unscaled: 2.2000 (2.2171)  loss_centroid_2_unscaled: 0.0540 (0.0569)  loss_ce_3_unscaled: 0.5304 (0.5221)  cardinality_error_3_unscaled: 2.2000 (2.2268)  loss_centroid_3_unscaled: 0.0529 (0.0566)  loss_ce_4_unscaled: 0.5329 (0.5220)  cardinality_error_4_unscaled: 2.2000 (2.2317)  loss_centroid_4_unscaled: 0.0555 (0.0574)  time: 0.6977  data: 0.2503  max mem: 4861
# Epoch: [2]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 4.7008 (4.7336)  loss_ce: 0.4947 (0.5117)  loss_centroid: 0.2719 (0.2770)  loss_ce_0: 0.5445 (0.5462)  loss_centroid_0: 0.2383 (0.2589)  loss_ce_1: 0.4972 (0.5135)  loss_centroid_1: 0.2595 (0.2712)  loss_ce_2: 0.5016 (0.5113)  loss_centroid_2: 0.2570 (0.2732)  loss_ce_3: 0.4979 (0.5123)  loss_centroid_3: 0.2593 (0.2710)  loss_ce_4: 0.4925 (0.5122)  loss_centroid_4: 0.2691 (0.2752)  loss_ce_unscaled: 0.4947 (0.5117)  class_error_unscaled: 100.0000 (99.9231)  cardinality_error_unscaled: 2.1000 (2.1660)  loss_centroid_unscaled: 0.0544 (0.0554)  loss_ce_0_unscaled: 0.5445 (0.5462)  cardinality_error_0_unscaled: 2.0000 (2.1300)  loss_centroid_0_unscaled: 0.0477 (0.0518)  loss_ce_1_unscaled: 0.4972 (0.5135)  cardinality_error_1_unscaled: 2.1000 (2.1600)  loss_centroid_1_unscaled: 0.0519 (0.0542)  loss_ce_2_unscaled: 0.5016 (0.5113)  cardinality_error_2_unscaled: 2.0000 (2.1560)  loss_centroid_2_unscaled: 0.0514 (0.0546)  loss_ce_3_unscaled: 0.4979 (0.5123)  cardinality_error_3_unscaled: 2.1000 (2.1580)  loss_centroid_3_unscaled: 0.0519 (0.0542)  loss_ce_4_unscaled: 0.4925 (0.5122)  cardinality_error_4_unscaled: 2.1000 (2.1640)  loss_centroid_4_unscaled: 0.0538 (0.0550)  time: 0.6509  data: 0.2130  max mem: 4861
# Epoch: [2] Total time: 0:00:32 (0.6550 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:26  class_error: 100.00  loss: 9.2656 (9.2656)  loss_ce: 0.5781 (0.5781)  loss_centroid: 0.9913 (0.9913)  loss_ce_0: 0.6319 (0.6319)  loss_centroid_0: 0.8925 (0.8925)  loss_ce_1: 0.5963 (0.5963)  loss_centroid_1: 0.9229 (0.9229)  loss_ce_2: 0.5834 (0.5834)  loss_centroid_2: 0.9418 (0.9418)  loss_ce_3: 0.5902 (0.5902)  loss_centroid_3: 0.9708 (0.9708)  loss_ce_4: 0.5819 (0.5819)  loss_centroid_4: 0.9843 (0.9843)  loss_ce_unscaled: 0.5781 (0.5781)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.1983 (0.1983)  loss_ce_0_unscaled: 0.6319 (0.6319)  cardinality_error_0_unscaled: 3.1000 (3.1000)  loss_centroid_0_unscaled: 0.1785 (0.1785)  loss_ce_1_unscaled: 0.5963 (0.5963)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.1846 (0.1846)  loss_ce_2_unscaled: 0.5834 (0.5834)  cardinality_error_2_unscaled: 3.1000 (3.1000)  loss_centroid_2_unscaled: 0.1884 (0.1884)  loss_ce_3_unscaled: 0.5902 (0.5902)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.1942 (0.1942)  loss_ce_4_unscaled: 0.5819 (0.5819)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.1969 (0.1969)  time: 5.2905  data: 4.3472  max mem: 4861
# Test:  [4/5]  eta: 0:00:02  class_error: 100.00  loss: 6.1962 (6.5334)  loss_ce: 0.4768 (0.4822)  loss_centroid: 0.6004 (0.6151)  loss_ce_0: 0.5328 (0.5334)  loss_centroid_0: 0.5149 (0.5568)  loss_ce_1: 0.4919 (0.5016)  loss_centroid_1: 0.5421 (0.5877)  loss_ce_2: 0.4887 (0.4879)  loss_centroid_2: 0.5907 (0.5880)  loss_ce_3: 0.4834 (0.4891)  loss_centroid_3: 0.5772 (0.5950)  loss_ce_4: 0.4862 (0.4849)  loss_centroid_4: 0.6119 (0.6117)  loss_ce_unscaled: 0.4768 (0.4822)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1200)  loss_centroid_unscaled: 0.1201 (0.1230)  loss_ce_0_unscaled: 0.5328 (0.5334)  cardinality_error_0_unscaled: 2.0000 (2.1400)  loss_centroid_0_unscaled: 0.1030 (0.1114)  loss_ce_1_unscaled: 0.4919 (0.5016)  cardinality_error_1_unscaled: 2.0000 (2.1400)  loss_centroid_1_unscaled: 0.1084 (0.1175)  loss_ce_2_unscaled: 0.4887 (0.4879)  cardinality_error_2_unscaled: 2.0000 (2.1400)  loss_centroid_2_unscaled: 0.1181 (0.1176)  loss_ce_3_unscaled: 0.4834 (0.4891)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.1154 (0.1190)  loss_ce_4_unscaled: 0.4862 (0.4849)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.1224 (0.1223)  time: 2.1083  data: 0.9049  max mem: 4861
# Test: Total time: 0:00:10 (2.1452 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [3]  [ 0/50]  eta: 0:04:44  lr: 0.000100  class_error: 100.00  loss: 3.9832 (3.9832)  loss_ce: 0.3966 (0.3966)  loss_centroid: 0.2484 (0.2484)  loss_ce_0: 0.4592 (0.4592)  loss_centroid_0: 0.2170 (0.2170)  loss_ce_1: 0.4156 (0.4156)  loss_centroid_1: 0.2537 (0.2537)  loss_ce_2: 0.3924 (0.3924)  loss_centroid_2: 0.2869 (0.2869)  loss_ce_3: 0.4012 (0.4012)  loss_centroid_3: 0.2651 (0.2651)  loss_ce_4: 0.3979 (0.3979)  loss_centroid_4: 0.2494 (0.2494)  loss_ce_unscaled: 0.3966 (0.3966)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.4000 (1.4000)  loss_centroid_unscaled: 0.0497 (0.0497)  loss_ce_0_unscaled: 0.4592 (0.4592)  cardinality_error_0_unscaled: 1.4000 (1.4000)  loss_centroid_0_unscaled: 0.0434 (0.0434)  loss_ce_1_unscaled: 0.4156 (0.4156)  cardinality_error_1_unscaled: 1.4000 (1.4000)  loss_centroid_1_unscaled: 0.0507 (0.0507)  loss_ce_2_unscaled: 0.3924 (0.3924)  cardinality_error_2_unscaled: 1.4000 (1.4000)  loss_centroid_2_unscaled: 0.0574 (0.0574)  loss_ce_3_unscaled: 0.4012 (0.4012)  cardinality_error_3_unscaled: 1.4000 (1.4000)  loss_centroid_3_unscaled: 0.0530 (0.0530)  loss_ce_4_unscaled: 0.3979 (0.3979)  cardinality_error_4_unscaled: 1.4000 (1.4000)  loss_centroid_4_unscaled: 0.0499 (0.0499)  time: 5.6838  data: 4.6641  max mem: 4861
# Epoch: [3]  [10/50]  eta: 0:00:40  lr: 0.000100  class_error: 100.00  loss: 4.3127 (4.3505)  loss_ce: 0.4329 (0.4673)  loss_centroid: 0.2484 (0.2545)  loss_ce_0: 0.4752 (0.4890)  loss_centroid_0: 0.2310 (0.2455)  loss_ce_1: 0.4406 (0.4679)  loss_centroid_1: 0.2505 (0.2524)  loss_ce_2: 0.4389 (0.4608)  loss_centroid_2: 0.2678 (0.2637)  loss_ce_3: 0.4257 (0.4661)  loss_centroid_3: 0.2617 (0.2609)  loss_ce_4: 0.4337 (0.4639)  loss_centroid_4: 0.2537 (0.2585)  loss_ce_unscaled: 0.4329 (0.4673)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.6000 (1.8636)  loss_centroid_unscaled: 0.0497 (0.0509)  loss_ce_0_unscaled: 0.4752 (0.4890)  cardinality_error_0_unscaled: 1.6000 (1.8455)  loss_centroid_0_unscaled: 0.0462 (0.0491)  loss_ce_1_unscaled: 0.4406 (0.4679)  cardinality_error_1_unscaled: 1.6000 (1.8727)  loss_centroid_1_unscaled: 0.0501 (0.0505)  loss_ce_2_unscaled: 0.4389 (0.4608)  cardinality_error_2_unscaled: 1.6000 (1.8545)  loss_centroid_2_unscaled: 0.0536 (0.0527)  loss_ce_3_unscaled: 0.4257 (0.4661)  cardinality_error_3_unscaled: 1.6000 (1.8545)  loss_centroid_3_unscaled: 0.0523 (0.0522)  loss_ce_4_unscaled: 0.4337 (0.4639)  cardinality_error_4_unscaled: 1.6000 (1.8636)  loss_centroid_4_unscaled: 0.0507 (0.0517)  time: 1.0225  data: 0.5153  max mem: 4861
# Epoch: [3]  [20/50]  eta: 0:00:24  lr: 0.000100  class_error: 100.00  loss: 4.4911 (4.4607)  loss_ce: 0.4638 (0.4840)  loss_centroid: 0.2389 (0.2591)  loss_ce_0: 0.4844 (0.5033)  loss_centroid_0: 0.2331 (0.2562)  loss_ce_1: 0.4658 (0.4824)  loss_centroid_1: 0.2505 (0.2519)  loss_ce_2: 0.4720 (0.4786)  loss_centroid_2: 0.2624 (0.2612)  loss_ce_3: 0.4662 (0.4842)  loss_centroid_3: 0.2589 (0.2585)  loss_ce_4: 0.4616 (0.4832)  loss_centroid_4: 0.2494 (0.2580)  loss_ce_unscaled: 0.4638 (0.4840)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.9000 (2.0429)  loss_centroid_unscaled: 0.0478 (0.0518)  loss_ce_0_unscaled: 0.4844 (0.5033)  cardinality_error_0_unscaled: 1.8000 (2.0238)  loss_centroid_0_unscaled: 0.0466 (0.0512)  loss_ce_1_unscaled: 0.4658 (0.4824)  cardinality_error_1_unscaled: 1.9000 (2.0476)  loss_centroid_1_unscaled: 0.0501 (0.0504)  loss_ce_2_unscaled: 0.4720 (0.4786)  cardinality_error_2_unscaled: 1.8000 (2.0381)  loss_centroid_2_unscaled: 0.0525 (0.0522)  loss_ce_3_unscaled: 0.4662 (0.4842)  cardinality_error_3_unscaled: 1.8000 (2.0381)  loss_centroid_3_unscaled: 0.0518 (0.0517)  loss_ce_4_unscaled: 0.4616 (0.4832)  cardinality_error_4_unscaled: 1.9000 (2.0429)  loss_centroid_4_unscaled: 0.0499 (0.0516)  time: 0.8184  data: 0.3284  max mem: 4861
# Epoch: [3]  [30/50]  eta: 0:00:14  lr: 0.000100  class_error: 100.00  loss: 4.3127 (4.4331)  loss_ce: 0.4588 (0.4805)  loss_centroid: 0.2389 (0.2586)  loss_ce_0: 0.4752 (0.4995)  loss_centroid_0: 0.2331 (0.2522)  loss_ce_1: 0.4658 (0.4777)  loss_centroid_1: 0.2516 (0.2528)  loss_ce_2: 0.4527 (0.4758)  loss_centroid_2: 0.2584 (0.2607)  loss_ce_3: 0.4642 (0.4803)  loss_centroid_3: 0.2488 (0.2586)  loss_ce_4: 0.4616 (0.4805)  loss_centroid_4: 0.2494 (0.2559)  loss_ce_unscaled: 0.4588 (0.4805)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.9000 (2.0839)  loss_centroid_unscaled: 0.0478 (0.0517)  loss_ce_0_unscaled: 0.4752 (0.4995)  cardinality_error_0_unscaled: 1.8000 (2.0645)  loss_centroid_0_unscaled: 0.0466 (0.0504)  loss_ce_1_unscaled: 0.4658 (0.4777)  cardinality_error_1_unscaled: 1.9000 (2.0871)  loss_centroid_1_unscaled: 0.0503 (0.0506)  loss_ce_2_unscaled: 0.4527 (0.4758)  cardinality_error_2_unscaled: 1.8000 (2.0806)  loss_centroid_2_unscaled: 0.0517 (0.0521)  loss_ce_3_unscaled: 0.4642 (0.4803)  cardinality_error_3_unscaled: 1.8000 (2.0806)  loss_centroid_3_unscaled: 0.0498 (0.0517)  loss_ce_4_unscaled: 0.4616 (0.4805)  cardinality_error_4_unscaled: 1.9000 (2.0839)  loss_centroid_4_unscaled: 0.0499 (0.0512)  time: 0.7108  data: 0.2434  max mem: 4861
# Epoch: [3]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 100.00  loss: 4.3127 (4.4153)  loss_ce: 0.4584 (0.4801)  loss_centroid: 0.2389 (0.2566)  loss_ce_0: 0.4828 (0.4972)  loss_centroid_0: 0.2318 (0.2453)  loss_ce_1: 0.4573 (0.4763)  loss_centroid_1: 0.2505 (0.2536)  loss_ce_2: 0.4527 (0.4753)  loss_centroid_2: 0.2584 (0.2593)  loss_ce_3: 0.4595 (0.4800)  loss_centroid_3: 0.2488 (0.2569)  loss_ce_4: 0.4594 (0.4800)  loss_centroid_4: 0.2473 (0.2546)  loss_ce_unscaled: 0.4584 (0.4801)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.9000 (2.0927)  loss_centroid_unscaled: 0.0478 (0.0513)  loss_ce_0_unscaled: 0.4828 (0.4972)  cardinality_error_0_unscaled: 1.8000 (2.0780)  loss_centroid_0_unscaled: 0.0464 (0.0491)  loss_ce_1_unscaled: 0.4573 (0.4763)  cardinality_error_1_unscaled: 1.9000 (2.0951)  loss_centroid_1_unscaled: 0.0501 (0.0507)  loss_ce_2_unscaled: 0.4527 (0.4753)  cardinality_error_2_unscaled: 1.8000 (2.0902)  loss_centroid_2_unscaled: 0.0517 (0.0519)  loss_ce_3_unscaled: 0.4595 (0.4800)  cardinality_error_3_unscaled: 1.8000 (2.0902)  loss_centroid_3_unscaled: 0.0498 (0.0514)  loss_ce_4_unscaled: 0.4594 (0.4800)  cardinality_error_4_unscaled: 1.9000 (2.0927)  loss_centroid_4_unscaled: 0.0495 (0.0509)  time: 0.6470  data: 0.1968  max mem: 4861
# Epoch: [3]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 4.3747 (4.4535)  loss_ce: 0.4638 (0.4862)  loss_centroid: 0.2409 (0.2576)  loss_ce_0: 0.4844 (0.5015)  loss_centroid_0: 0.2334 (0.2504)  loss_ce_1: 0.4658 (0.4819)  loss_centroid_1: 0.2382 (0.2513)  loss_ce_2: 0.4692 (0.4820)  loss_centroid_2: 0.2493 (0.2581)  loss_ce_3: 0.4674 (0.4873)  loss_centroid_3: 0.2380 (0.2559)  loss_ce_4: 0.4639 (0.4867)  loss_centroid_4: 0.2473 (0.2546)  loss_ce_unscaled: 0.4638 (0.4862)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.9000 (2.1640)  loss_centroid_unscaled: 0.0482 (0.0515)  loss_ce_0_unscaled: 0.4844 (0.5015)  cardinality_error_0_unscaled: 1.9000 (2.1420)  loss_centroid_0_unscaled: 0.0467 (0.0501)  loss_ce_1_unscaled: 0.4658 (0.4819)  cardinality_error_1_unscaled: 1.9000 (2.1620)  loss_centroid_1_unscaled: 0.0476 (0.0503)  loss_ce_2_unscaled: 0.4692 (0.4820)  cardinality_error_2_unscaled: 1.9000 (2.1620)  loss_centroid_2_unscaled: 0.0499 (0.0516)  loss_ce_3_unscaled: 0.4674 (0.4873)  cardinality_error_3_unscaled: 1.9000 (2.1620)  loss_centroid_3_unscaled: 0.0476 (0.0512)  loss_ce_4_unscaled: 0.4639 (0.4867)  cardinality_error_4_unscaled: 1.9000 (2.1640)  loss_centroid_4_unscaled: 0.0495 (0.0509)  time: 0.6036  data: 0.1656  max mem: 4861
# Epoch: [3] Total time: 0:00:30 (0.6091 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:27  class_error: 100.00  loss: 10.5764 (10.5764)  loss_ce: 0.5687 (0.5687)  loss_centroid: 1.2109 (1.2109)  loss_ce_0: 0.6090 (0.6090)  loss_centroid_0: 1.1320 (1.1320)  loss_ce_1: 0.5908 (0.5908)  loss_centroid_1: 1.1594 (1.1594)  loss_ce_2: 0.5749 (0.5749)  loss_centroid_2: 1.1680 (1.1680)  loss_ce_3: 0.5876 (0.5876)  loss_centroid_3: 1.2040 (1.2040)  loss_ce_4: 0.5719 (0.5719)  loss_centroid_4: 1.1992 (1.1992)  loss_ce_unscaled: 0.5687 (0.5687)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.2422 (0.2422)  loss_ce_0_unscaled: 0.6090 (0.6090)  cardinality_error_0_unscaled: 3.1000 (3.1000)  loss_centroid_0_unscaled: 0.2264 (0.2264)  loss_ce_1_unscaled: 0.5908 (0.5908)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.2319 (0.2319)  loss_ce_2_unscaled: 0.5749 (0.5749)  cardinality_error_2_unscaled: 3.1000 (3.1000)  loss_centroid_2_unscaled: 0.2336 (0.2336)  loss_ce_3_unscaled: 0.5876 (0.5876)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.2408 (0.2408)  loss_ce_4_unscaled: 0.5719 (0.5719)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.2398 (0.2398)  time: 5.4826  data: 4.5500  max mem: 4861
# Test:  [4/5]  eta: 0:00:02  class_error: 100.00  loss: 7.2104 (7.4339)  loss_ce: 0.4798 (0.4786)  loss_centroid: 0.7792 (0.7667)  loss_ce_0: 0.5258 (0.5152)  loss_centroid_0: 0.7102 (0.7254)  loss_ce_1: 0.5036 (0.4979)  loss_centroid_1: 0.7084 (0.7395)  loss_ce_2: 0.4969 (0.4886)  loss_centroid_2: 0.7420 (0.7363)  loss_ce_3: 0.4874 (0.4883)  loss_centroid_3: 0.7525 (0.7508)  loss_ce_4: 0.4886 (0.4819)  loss_centroid_4: 0.7913 (0.7650)  loss_ce_unscaled: 0.4798 (0.4786)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1400)  loss_centroid_unscaled: 0.1558 (0.1533)  loss_ce_0_unscaled: 0.5258 (0.5152)  cardinality_error_0_unscaled: 2.0000 (2.1400)  loss_centroid_0_unscaled: 0.1420 (0.1451)  loss_ce_1_unscaled: 0.5036 (0.4979)  cardinality_error_1_unscaled: 2.0000 (2.1400)  loss_centroid_1_unscaled: 0.1417 (0.1479)  loss_ce_2_unscaled: 0.4969 (0.4886)  cardinality_error_2_unscaled: 2.0000 (2.1400)  loss_centroid_2_unscaled: 0.1484 (0.1473)  loss_ce_3_unscaled: 0.4874 (0.4883)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.1505 (0.1502)  loss_ce_4_unscaled: 0.4886 (0.4819)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.1583 (0.1530)  time: 2.1196  data: 0.9370  max mem: 4861
# Test: Total time: 0:00:10 (2.1527 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [4]  [ 0/50]  eta: 0:04:24  lr: 0.000100  class_error: 100.00  loss: 4.3859 (4.3859)  loss_ce: 0.4686 (0.4686)  loss_centroid: 0.2694 (0.2694)  loss_ce_0: 0.4785 (0.4785)  loss_centroid_0: 0.2441 (0.2441)  loss_ce_1: 0.4762 (0.4762)  loss_centroid_1: 0.2391 (0.2391)  loss_ce_2: 0.4680 (0.4680)  loss_centroid_2: 0.2818 (0.2818)  loss_ce_3: 0.4856 (0.4856)  loss_centroid_3: 0.2496 (0.2496)  loss_ce_4: 0.4617 (0.4617)  loss_centroid_4: 0.2634 (0.2634)  loss_ce_unscaled: 0.4686 (0.4686)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.0000)  loss_centroid_unscaled: 0.0539 (0.0539)  loss_ce_0_unscaled: 0.4785 (0.4785)  cardinality_error_0_unscaled: 1.9000 (1.9000)  loss_centroid_0_unscaled: 0.0488 (0.0488)  loss_ce_1_unscaled: 0.4762 (0.4762)  cardinality_error_1_unscaled: 2.0000 (2.0000)  loss_centroid_1_unscaled: 0.0478 (0.0478)  loss_ce_2_unscaled: 0.4680 (0.4680)  cardinality_error_2_unscaled: 2.0000 (2.0000)  loss_centroid_2_unscaled: 0.0564 (0.0564)  loss_ce_3_unscaled: 0.4856 (0.4856)  cardinality_error_3_unscaled: 2.0000 (2.0000)  loss_centroid_3_unscaled: 0.0499 (0.0499)  loss_ce_4_unscaled: 0.4617 (0.4617)  cardinality_error_4_unscaled: 2.0000 (2.0000)  loss_centroid_4_unscaled: 0.0527 (0.0527)  time: 5.2959  data: 3.2229  max mem: 4861
# Epoch: [4]  [10/50]  eta: 0:00:50  lr: 0.000100  class_error: 100.00  loss: 4.1044 (4.2053)  loss_ce: 0.4686 (0.4763)  loss_centroid: 0.2298 (0.2291)  loss_ce_0: 0.4797 (0.4887)  loss_centroid_0: 0.2299 (0.2208)  loss_ce_1: 0.4727 (0.4736)  loss_centroid_1: 0.2168 (0.2158)  loss_ce_2: 0.4680 (0.4717)  loss_centroid_2: 0.2320 (0.2237)  loss_ce_3: 0.4796 (0.4820)  loss_centroid_3: 0.2242 (0.2187)  loss_ce_4: 0.4617 (0.4759)  loss_centroid_4: 0.2315 (0.2290)  loss_ce_unscaled: 0.4686 (0.4763)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.3000 (2.3091)  loss_centroid_unscaled: 0.0460 (0.0458)  loss_ce_0_unscaled: 0.4797 (0.4887)  cardinality_error_0_unscaled: 2.3000 (2.2273)  loss_centroid_0_unscaled: 0.0460 (0.0442)  loss_ce_1_unscaled: 0.4727 (0.4736)  cardinality_error_1_unscaled: 2.3000 (2.3000)  loss_centroid_1_unscaled: 0.0434 (0.0432)  loss_ce_2_unscaled: 0.4680 (0.4717)  cardinality_error_2_unscaled: 2.3000 (2.3091)  loss_centroid_2_unscaled: 0.0464 (0.0447)  loss_ce_3_unscaled: 0.4796 (0.4820)  cardinality_error_3_unscaled: 2.3000 (2.3091)  loss_centroid_3_unscaled: 0.0448 (0.0437)  loss_ce_4_unscaled: 0.4617 (0.4759)  cardinality_error_4_unscaled: 2.3000 (2.3091)  loss_centroid_4_unscaled: 0.0463 (0.0458)  time: 1.2702  data: 0.5764  max mem: 4861
# ...
# Epoch: [18]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 33.33  loss: 2.0313 (2.0387)  loss_ce: 0.1220 (0.1306)  loss_centroid: 0.1946 (0.1967)  loss_ce_0: 0.1411 (0.1502)  loss_centroid_0: 0.2160 (0.2180)  loss_ce_1: 0.1349 (0.1410)  loss_centroid_1: 0.1997 (0.2102)  loss_ce_2: 0.1249 (0.1346)  loss_centroid_2: 0.1964 (0.2025)  loss_ce_3: 0.1267 (0.1339)  loss_centroid_3: 0.1893 (0.1934)  loss_ce_4: 0.1239 (0.1313)  loss_centroid_4: 0.1928 (0.1961)  loss_ce_unscaled: 0.1220 (0.1306)  class_error_unscaled: 12.5000 (13.7910)  cardinality_error_unscaled: 1.0000 (1.0683)  loss_centroid_unscaled: 0.0389 (0.0393)  loss_ce_0_unscaled: 0.1411 (0.1502)  cardinality_error_0_unscaled: 1.5000 (1.6000)  loss_centroid_0_unscaled: 0.0432 (0.0436)  loss_ce_1_unscaled: 0.1349 (0.1410)  cardinality_error_1_unscaled: 1.2000 (1.4122)  loss_centroid_1_unscaled: 0.0399 (0.0420)  loss_ce_2_unscaled: 0.1249 (0.1346)  cardinality_error_2_unscaled: 1.1000 (1.2854)  loss_centroid_2_unscaled: 0.0393 (0.0405)  loss_ce_3_unscaled: 0.1267 (0.1339)  cardinality_error_3_unscaled: 0.9000 (1.0366)  loss_centroid_3_unscaled: 0.0379 (0.0387)  loss_ce_4_unscaled: 0.1239 (0.1313)  cardinality_error_4_unscaled: 0.9000 (1.1024)  loss_centroid_4_unscaled: 0.0386 (0.0392)  time: 0.6884  data: 0.2365  max mem: 4861
# Epoch: [18]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 5.26  loss: 2.0313 (2.0730)  loss_ce: 0.1220 (0.1337)  loss_centroid: 0.1946 (0.1982)  loss_ce_0: 0.1448 (0.1527)  loss_centroid_0: 0.2220 (0.2235)  loss_ce_1: 0.1349 (0.1422)  loss_centroid_1: 0.2022 (0.2153)  loss_ce_2: 0.1249 (0.1364)  loss_centroid_2: 0.1981 (0.2060)  loss_ce_3: 0.1267 (0.1361)  loss_centroid_3: 0.1893 (0.1965)  loss_ce_4: 0.1239 (0.1340)  loss_centroid_4: 0.1950 (0.1983)  loss_ce_unscaled: 0.1220 (0.1337)  class_error_unscaled: 13.7931 (14.3701)  cardinality_error_unscaled: 0.8000 (1.0680)  loss_centroid_unscaled: 0.0389 (0.0396)  loss_ce_0_unscaled: 0.1448 (0.1527)  cardinality_error_0_unscaled: 1.5000 (1.6280)  loss_centroid_0_unscaled: 0.0444 (0.0447)  loss_ce_1_unscaled: 0.1349 (0.1422)  cardinality_error_1_unscaled: 1.2000 (1.4360)  loss_centroid_1_unscaled: 0.0404 (0.0431)  loss_ce_2_unscaled: 0.1249 (0.1364)  cardinality_error_2_unscaled: 1.1000 (1.2960)  loss_centroid_2_unscaled: 0.0396 (0.0412)  loss_ce_3_unscaled: 0.1267 (0.1361)  cardinality_error_3_unscaled: 0.9000 (1.0340)  loss_centroid_3_unscaled: 0.0379 (0.0393)  loss_ce_4_unscaled: 0.1239 (0.1340)  cardinality_error_4_unscaled: 0.8000 (1.0980)  loss_centroid_4_unscaled: 0.0390 (0.0397)  time: 0.6405  data: 0.1967  max mem: 4861
# Epoch: [18] Total time: 0:00:32 (0.6446 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:29  class_error: 54.84  loss: 11.5737 (11.5737)  loss_ce: 0.5916 (0.5916)  loss_centroid: 1.3295 (1.3295)  loss_ce_0: 0.6683 (0.6683)  loss_centroid_0: 1.2985 (1.2985)  loss_ce_1: 0.6152 (0.6152)  loss_centroid_1: 1.3153 (1.3153)  loss_ce_2: 0.5509 (0.5509)  loss_centroid_2: 1.3456 (1.3456)  loss_ce_3: 0.5962 (0.5962)  loss_centroid_3: 1.3228 (1.3228)  loss_ce_4: 0.5976 (0.5976)  loss_centroid_4: 1.3422 (1.3422)  loss_ce_unscaled: 0.5916 (0.5916)  class_error_unscaled: 54.8387 (54.8387)  cardinality_error_unscaled: 1.2000 (1.2000)  loss_centroid_unscaled: 0.2659 (0.2659)  loss_ce_0_unscaled: 0.6683 (0.6683)  cardinality_error_0_unscaled: 2.7000 (2.7000)  loss_centroid_0_unscaled: 0.2597 (0.2597)  loss_ce_1_unscaled: 0.6152 (0.6152)  cardinality_error_1_unscaled: 2.1000 (2.1000)  loss_centroid_1_unscaled: 0.2631 (0.2631)  loss_ce_2_unscaled: 0.5509 (0.5509)  cardinality_error_2_unscaled: 1.6000 (1.6000)  loss_centroid_2_unscaled: 0.2691 (0.2691)  loss_ce_3_unscaled: 0.5962 (0.5962)  cardinality_error_3_unscaled: 1.3000 (1.3000)  loss_centroid_3_unscaled: 0.2646 (0.2646)  loss_ce_4_unscaled: 0.5976 (0.5976)  cardinality_error_4_unscaled: 1.1000 (1.1000)  loss_centroid_4_unscaled: 0.2684 (0.2684)  time: 5.8379  data: 4.8832  max mem: 4861
# Test:  [4/5]  eta: 0:00:02  class_error: 86.36  loss: 8.3327 (9.0735)  loss_ce: 0.5720 (0.5556)  loss_centroid: 0.9363 (0.9443)  loss_ce_0: 0.6548 (0.6322)  loss_centroid_0: 0.8085 (0.8776)  loss_ce_1: 0.6152 (0.6107)  loss_centroid_1: 0.7639 (0.9366)  loss_ce_2: 0.5509 (0.5649)  loss_centroid_2: 0.8956 (0.9482)  loss_ce_3: 0.5593 (0.5621)  loss_centroid_3: 0.8751 (0.9434)  loss_ce_4: 0.5528 (0.5469)  loss_centroid_4: 0.9456 (0.9510)  loss_ce_unscaled: 0.5720 (0.5556)  class_error_unscaled: 80.0000 (71.8194)  cardinality_error_unscaled: 0.8000 (0.7000)  loss_centroid_unscaled: 0.1873 (0.1889)  loss_ce_0_unscaled: 0.6548 (0.6322)  cardinality_error_0_unscaled: 1.5000 (1.5400)  loss_centroid_0_unscaled: 0.1617 (0.1755)  loss_ce_1_unscaled: 0.6152 (0.6107)  cardinality_error_1_unscaled: 0.7000 (1.1200)  loss_centroid_1_unscaled: 0.1528 (0.1873)  loss_ce_2_unscaled: 0.5509 (0.5649)  cardinality_error_2_unscaled: 0.8000 (0.8000)  loss_centroid_2_unscaled: 0.1791 (0.1896)  loss_ce_3_unscaled: 0.5593 (0.5621)  cardinality_error_3_unscaled: 0.8000 (0.7000)  loss_centroid_3_unscaled: 0.1750 (0.1887)  loss_ce_4_unscaled: 0.5528 (0.5469)  cardinality_error_4_unscaled: 0.8000 (0.6800)  loss_centroid_4_unscaled: 0.1891 (0.1902)  time: 2.2117  data: 1.0164  max mem: 4861
# Test: Total time: 0:00:11 (2.2550 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [19]  [ 0/50]  eta: 0:05:39  lr: 0.000100  class_error: 11.11  loss: 2.5632 (2.5632)  loss_ce: 0.1456 (0.1456)  loss_centroid: 0.2817 (0.2817)  loss_ce_0: 0.1295 (0.1295)  loss_centroid_0: 0.3487 (0.3487)  loss_ce_1: 0.1382 (0.1382)  loss_centroid_1: 0.2763 (0.2763)  loss_ce_2: 0.1266 (0.1266)  loss_centroid_2: 0.2724 (0.2724)  loss_ce_3: 0.1201 (0.1201)  loss_centroid_3: 0.2966 (0.2966)  loss_ce_4: 0.1490 (0.1490)  loss_centroid_4: 0.2785 (0.2785)  loss_ce_unscaled: 0.1456 (0.1456)  class_error_unscaled: 11.1111 (11.1111)  cardinality_error_unscaled: 1.1000 (1.1000)  loss_centroid_unscaled: 0.0563 (0.0563)  loss_ce_0_unscaled: 0.1295 (0.1295)  cardinality_error_0_unscaled: 3.0000 (3.0000)  loss_centroid_0_unscaled: 0.0697 (0.0697)  loss_ce_1_unscaled: 0.1382 (0.1382)  cardinality_error_1_unscaled: 1.7000 (1.7000)  loss_centroid_1_unscaled: 0.0553 (0.0553)  loss_ce_2_unscaled: 0.1266 (0.1266)  cardinality_error_2_unscaled: 1.6000 (1.6000)  loss_centroid_2_unscaled: 0.0545 (0.0545)  loss_ce_3_unscaled: 0.1201 (0.1201)  cardinality_error_3_unscaled: 1.4000 (1.4000)  loss_centroid_3_unscaled: 0.0593 (0.0593)  loss_ce_4_unscaled: 0.1490 (0.1490)  cardinality_error_4_unscaled: 1.5000 (1.5000)  loss_centroid_4_unscaled: 0.0557 (0.0557)  time: 6.7971  data: 5.7945  max mem: 4861
# Epoch: [19]  [10/50]  eta: 0:00:45  lr: 0.000100  class_error: 12.50  loss: 1.8357 (1.8882)  loss_ce: 0.1273 (0.1175)  loss_centroid: 0.1764 (0.1825)  loss_ce_0: 0.1259 (0.1249)  loss_centroid_0: 0.2132 (0.2208)  loss_ce_1: 0.1195 (0.1206)  loss_centroid_1: 0.2002 (0.2032)  loss_ce_2: 0.1266 (0.1191)  loss_centroid_2: 0.1971 (0.1952)  loss_ce_3: 0.1201 (0.1139)  loss_centroid_3: 0.1796 (0.1899)  loss_ce_4: 0.1203 (0.1168)  loss_centroid_4: 0.1723 (0.1839)  loss_ce_unscaled: 0.1273 (0.1175)  class_error_unscaled: 11.7647 (12.3647)  cardinality_error_unscaled: 0.8000 (1.0818)  loss_centroid_unscaled: 0.0353 (0.0365)  loss_ce_0_unscaled: 0.1259 (0.1249)  cardinality_error_0_unscaled: 1.4000 (1.8727)  loss_centroid_0_unscaled: 0.0426 (0.0442)  loss_ce_1_unscaled: 0.1195 (0.1206)  cardinality_error_1_unscaled: 1.7000 (1.7091)  loss_centroid_1_unscaled: 0.0400 (0.0406)  loss_ce_2_unscaled: 0.1266 (0.1191)  cardinality_error_2_unscaled: 1.3000 (1.5545)  loss_centroid_2_unscaled: 0.0394 (0.0390)  loss_ce_3_unscaled: 0.1201 (0.1139)  cardinality_error_3_unscaled: 0.7000 (1.2182)  loss_centroid_3_unscaled: 0.0359 (0.0380)  loss_ce_4_unscaled: 0.1203 (0.1168)  cardinality_error_4_unscaled: 0.8000 (1.2000)  loss_centroid_4_unscaled: 0.0345 (0.0368)  time: 1.1449  data: 0.6161  max mem: 4861
# Epoch: [19]  [20/50]  eta: 0:00:25  lr: 0.000100  class_error: 4.17  loss: 1.8390 (1.9598)  loss_ce: 0.1273 (0.1200)  loss_centroid: 0.1810 (0.1904)  loss_ce_0: 0.1305 (0.1337)  loss_centroid_0: 0.2182 (0.2279)  loss_ce_1: 0.1283 (0.1262)  loss_centroid_1: 0.2098 (0.2116)  loss_ce_2: 0.1329 (0.1249)  loss_centroid_2: 0.2009 (0.1993)  loss_ce_3: 0.1217 (0.1201)  loss_centroid_3: 0.1811 (0.1939)  loss_ce_4: 0.1290 (0.1213)  loss_centroid_4: 0.1775 (0.1905)  loss_ce_unscaled: 0.1273 (0.1200)  class_error_unscaled: 11.7647 (12.6447)  cardinality_error_unscaled: 0.9000 (1.0048)  loss_centroid_unscaled: 0.0362 (0.0381)  loss_ce_0_unscaled: 0.1305 (0.1337)  cardinality_error_0_unscaled: 1.4000 (1.5905)  loss_centroid_0_unscaled: 0.0436 (0.0456)  loss_ce_1_unscaled: 0.1283 (0.1262)  cardinality_error_1_unscaled: 1.2000 (1.5000)  loss_centroid_1_unscaled: 0.0420 (0.0423)  loss_ce_2_unscaled: 0.1329 (0.1249)  cardinality_error_2_unscaled: 1.1000 (1.2905)  loss_centroid_2_unscaled: 0.0402 (0.0399)  loss_ce_3_unscaled: 0.1217 (0.1201)  cardinality_error_3_unscaled: 1.0000 (1.0667)  loss_centroid_3_unscaled: 0.0362 (0.0388)  loss_ce_4_unscaled: 0.1290 (0.1213)  cardinality_error_4_unscaled: 0.9000 (1.1000)  loss_centroid_4_unscaled: 0.0355 (0.0381)  time: 0.8516  data: 0.3750  max mem: 4861
# Epoch: [19]  [30/50]  eta: 0:00:14  lr: 0.000100  class_error: 29.41  loss: 1.9915 (2.0269)  loss_ce: 0.1290 (0.1244)  loss_centroid: 0.1838 (0.1966)  loss_ce_0: 0.1386 (0.1444)  loss_centroid_0: 0.2190 (0.2273)  loss_ce_1: 0.1373 (0.1329)  loss_centroid_1: 0.2098 (0.2139)  loss_ce_2: 0.1329 (0.1278)  loss_centroid_2: 0.2041 (0.2089)  loss_ce_3: 0.1306 (0.1258)  loss_centroid_3: 0.1877 (0.2000)  loss_ce_4: 0.1291 (0.1268)  loss_centroid_4: 0.1944 (0.1980)  loss_ce_unscaled: 0.1290 (0.1244)  class_error_unscaled: 12.5000 (14.3897)  cardinality_error_unscaled: 0.9000 (0.9871)  loss_centroid_unscaled: 0.0368 (0.0393)  loss_ce_0_unscaled: 0.1386 (0.1444)  cardinality_error_0_unscaled: 1.4000 (1.6323)  loss_centroid_0_unscaled: 0.0438 (0.0455)  loss_ce_1_unscaled: 0.1373 (0.1329)  cardinality_error_1_unscaled: 1.5000 (1.4516)  loss_centroid_1_unscaled: 0.0420 (0.0428)  loss_ce_2_unscaled: 0.1329 (0.1278)  cardinality_error_2_unscaled: 1.1000 (1.2355)  loss_centroid_2_unscaled: 0.0408 (0.0418)  loss_ce_3_unscaled: 0.1306 (0.1258)  cardinality_error_3_unscaled: 0.9000 (1.0419)  loss_centroid_3_unscaled: 0.0375 (0.0400)  loss_ce_4_unscaled: 0.1291 (0.1268)  cardinality_error_4_unscaled: 0.9000 (1.0774)  loss_centroid_4_unscaled: 0.0389 (0.0396)  time: 0.7259  data: 0.2710  max mem: 4861
# Epoch: [19]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 6.45  loss: 1.9993 (2.0371)  loss_ce: 0.1290 (0.1246)  loss_centroid: 0.1957 (0.2010)  loss_ce_0: 0.1402 (0.1445)  loss_centroid_0: 0.2194 (0.2292)  loss_ce_1: 0.1361 (0.1319)  loss_centroid_1: 0.2098 (0.2141)  loss_ce_2: 0.1281 (0.1262)  loss_centroid_2: 0.2075 (0.2116)  loss_ce_3: 0.1306 (0.1255)  loss_centroid_3: 0.1930 (0.2013)  loss_ce_4: 0.1295 (0.1268)  loss_centroid_4: 0.2012 (0.2003)  loss_ce_unscaled: 0.1290 (0.1246)  class_error_unscaled: 11.7647 (13.9697)  cardinality_error_unscaled: 0.9000 (1.0244)  loss_centroid_unscaled: 0.0391 (0.0402)  loss_ce_0_unscaled: 0.1402 (0.1445)  cardinality_error_0_unscaled: 1.4000 (1.5878)  loss_centroid_0_unscaled: 0.0439 (0.0458)  loss_ce_1_unscaled: 0.1361 (0.1319)  cardinality_error_1_unscaled: 1.3000 (1.4220)  loss_centroid_1_unscaled: 0.0420 (0.0428)  loss_ce_2_unscaled: 0.1281 (0.1262)  cardinality_error_2_unscaled: 1.1000 (1.2585)  loss_centroid_2_unscaled: 0.0415 (0.0423)  loss_ce_3_unscaled: 0.1306 (0.1255)  cardinality_error_3_unscaled: 0.9000 (1.0463)  loss_centroid_3_unscaled: 0.0386 (0.0403)  loss_ce_4_unscaled: 0.1295 (0.1268)  cardinality_error_4_unscaled: 0.9000 (1.1122)  loss_centroid_4_unscaled: 0.0402 (0.0401)  time: 0.6593  data: 0.2176  max mem: 4861
# Epoch: [19]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 11.11  loss: 1.9993 (2.0268)  loss_ce: 0.1290 (0.1253)  loss_centroid: 0.1896 (0.1977)  loss_ce_0: 0.1402 (0.1454)  loss_centroid_0: 0.2190 (0.2273)  loss_ce_1: 0.1361 (0.1336)  loss_centroid_1: 0.2054 (0.2113)  loss_ce_2: 0.1281 (0.1268)  loss_centroid_2: 0.2075 (0.2103)  loss_ce_3: 0.1306 (0.1268)  loss_centroid_3: 0.1867 (0.1977)  loss_ce_4: 0.1295 (0.1276)  loss_centroid_4: 0.1933 (0.1970)  loss_ce_unscaled: 0.1290 (0.1253)  class_error_unscaled: 11.7647 (13.8476)  cardinality_error_unscaled: 0.9000 (1.0160)  loss_centroid_unscaled: 0.0379 (0.0395)  loss_ce_0_unscaled: 0.1402 (0.1454)  cardinality_error_0_unscaled: 1.3000 (1.5580)  loss_centroid_0_unscaled: 0.0438 (0.0455)  loss_ce_1_unscaled: 0.1361 (0.1336)  cardinality_error_1_unscaled: 1.3000 (1.4000)  loss_centroid_1_unscaled: 0.0411 (0.0423)  loss_ce_2_unscaled: 0.1281 (0.1268)  cardinality_error_2_unscaled: 1.1000 (1.2460)  loss_centroid_2_unscaled: 0.0415 (0.0421)  loss_ce_3_unscaled: 0.1306 (0.1268)  cardinality_error_3_unscaled: 0.9000 (1.0160)  loss_centroid_3_unscaled: 0.0373 (0.0395)  loss_ce_4_unscaled: 0.1295 (0.1276)  cardinality_error_4_unscaled: 1.0000 (1.0880)  loss_centroid_4_unscaled: 0.0387 (0.0394)  time: 0.6177  data: 0.1829  max mem: 4861
# Epoch: [19] Total time: 0:00:31 (0.6246 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:20  class_error: 58.06  loss: 11.2603 (11.2603)  loss_ce: 0.6158 (0.6158)  loss_centroid: 1.2516 (1.2516)  loss_ce_0: 0.6728 (0.6728)  loss_centroid_0: 1.2761 (1.2761)  loss_ce_1: 0.6221 (0.6221)  loss_centroid_1: 1.2361 (1.2361)  loss_ce_2: 0.5637 (0.5637)  loss_centroid_2: 1.2831 (1.2831)  loss_ce_3: 0.5846 (0.5846)  loss_centroid_3: 1.2721 (1.2721)  loss_ce_4: 0.6217 (0.6217)  loss_centroid_4: 1.2607 (1.2607)  loss_ce_unscaled: 0.6158 (0.6158)  class_error_unscaled: 58.0645 (58.0645)  cardinality_error_unscaled: 1.6000 (1.6000)  loss_centroid_unscaled: 0.2503 (0.2503)  loss_ce_0_unscaled: 0.6728 (0.6728)  cardinality_error_0_unscaled: 2.6000 (2.6000)  loss_centroid_0_unscaled: 0.2552 (0.2552)  loss_ce_1_unscaled: 0.6221 (0.6221)  cardinality_error_1_unscaled: 2.3000 (2.3000)  loss_centroid_1_unscaled: 0.2472 (0.2472)  loss_ce_2_unscaled: 0.5637 (0.5637)  cardinality_error_2_unscaled: 1.7000 (1.7000)  loss_centroid_2_unscaled: 0.2566 (0.2566)  loss_ce_3_unscaled: 0.5846 (0.5846)  cardinality_error_3_unscaled: 1.5000 (1.5000)  loss_centroid_3_unscaled: 0.2544 (0.2544)  loss_ce_4_unscaled: 0.6217 (0.6217)  cardinality_error_4_unscaled: 1.6000 (1.6000)  loss_centroid_4_unscaled: 0.2521 (0.2521)  time: 4.1279  data: 3.1152  max mem: 4861
# Test:  [4/5]  eta: 0:00:01  class_error: 81.82  loss: 8.4240 (8.9118)  loss_ce: 0.6084 (0.5797)  loss_centroid: 0.8414 (0.8897)  loss_ce_0: 0.6728 (0.6452)  loss_centroid_0: 0.7334 (0.8459)  loss_ce_1: 0.6221 (0.6237)  loss_centroid_1: 0.7174 (0.8767)  loss_ce_2: 0.5874 (0.5903)  loss_centroid_2: 0.7806 (0.9073)  loss_ce_3: 0.5834 (0.5864)  loss_centroid_3: 0.7740 (0.8872)  loss_ce_4: 0.5698 (0.5689)  loss_centroid_4: 0.9038 (0.9108)  loss_ce_unscaled: 0.6084 (0.5797)  class_error_unscaled: 80.0000 (72.6081)  cardinality_error_unscaled: 0.8000 (0.8200)  loss_centroid_unscaled: 0.1683 (0.1779)  loss_ce_0_unscaled: 0.6728 (0.6452)  cardinality_error_0_unscaled: 1.4000 (1.5400)  loss_centroid_0_unscaled: 0.1467 (0.1692)  loss_ce_1_unscaled: 0.6221 (0.6237)  cardinality_error_1_unscaled: 0.7000 (1.1600)  loss_centroid_1_unscaled: 0.1435 (0.1753)  loss_ce_2_unscaled: 0.5874 (0.5903)  cardinality_error_2_unscaled: 0.8000 (0.8400)  loss_centroid_2_unscaled: 0.1561 (0.1815)  loss_ce_3_unscaled: 0.5834 (0.5864)  cardinality_error_3_unscaled: 0.9000 (0.8400)  loss_centroid_3_unscaled: 0.1548 (0.1774)  loss_ce_4_unscaled: 0.5698 (0.5689)  cardinality_error_4_unscaled: 0.7000 (0.8000)  loss_centroid_4_unscaled: 0.1808 (0.1822)  time: 1.8674  data: 0.6635  max mem: 4861
# Test: Total time: 0:00:09 (1.9039 s / it)
# Training time 0:14:20

# %% [markdown]
# ## Visualizing
# ---------------

# %%
device = torch.device('cuda')
# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])



def rescale_center(out_bbox, size):
    img_w, img_h = size
    b = out_bbox * torch.tensor([img_w, img_h], dtype=torch.float32, device=device)
    return b

def detect(im, model, transform, det_threshold = 0.75):
    # mean-std normalize the input image (batch-size: 1)
    img = transform(im).unsqueeze(0)

    # demo model only support by default images with aspect ratio between 0.5 and 2
    # if you want to use images with an aspect ratio outside this range
    # rescale your image so that the maximum size is at most 1333 for best results
    assert img.shape[-2] <= 1600 and img.shape[-1] <= 1600, 'demo model only supports images up to 1600 pixels on each side'

    # propagate through the model
    outputs = model(img.to(device))

    # keep only predictions with 0.7+ confidence
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > det_threshold

    # convert boxes from [0; 1] to image scales
    centroids = rescale_center(outputs['pred_centroids'][0, keep], im.size)
    return probas[keep].detach().cpu(), centroids.detach().cpu()

def getImg(url):
    return Image.open(requests.get(url, stream=True).raw)

def is_grayscale(image):
    if image.mode == "L":
        return True
    else:
        return False

def convert_grayscale_to_rgb(image):
    if not is_grayscale(image):
        return image
    else:
        return image.convert("RGB")


def plot_results(pil_img, prob, centroids, gt_centroids, boxes, file_name):
    # plt.figure(figsize=(16, 10))
    plt.imshow(pil_img)
    ax = plt.gca()
    ax.scatter([c[0] for c in gt_centroids], [c[1] for c in gt_centroids], color='blue', s=10)
    ax.scatter([c[0] for c in centroids], [c[1] for c in centroids.cpu()], color='red', s=10)
    if show_center:
        ax.scatter([c[0]+c[2]//2 for c in boxes], [c[1]+c[3]//2 for c in boxes], color='green', s=10)
    for (xc, yc, w, h), c in zip(boxes, COLORS * 100):
        ax.add_patch(plt.Rectangle((xc, yc), w, h,
                                   fill=False, color='white', linewidth=2))
    if show_probs:
        for p, c in zip(prob, centroids):
            cl = p.argmax()
            text = f'- {p[cl]:0.2f}'
            ax.text(c[0] + 15, c[1], text, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.5))
    plt.axis('off')
    # plt.savefig(f'images/{file_name}')
    plt.show()

# %% [markdown]
# ### before submission run below cell with display_results=True

# %%
display_results = True
show_probs = True
show_center = True
det_threshold = 0.7

model = _make_detr('resnet50', num_classes=2)
model.to(device)

checkpoint = torch.load('checkpoints/checkpoint.pth', map_location='cpu')
print("DETR returning", {n:p for n,p in model.named_parameters()}.keys())

model.load_state_dict(checkpoint['model'])
model.eval()
if not os.path.exists('images'):
    os.mkdir('images')

coco = COCO(PATH_TO_COCO + 'annotations/instances_val2017.json')
ids = coco.getImgIds()

val_drift_rates = []
for id in range(20):
    im = coco.loadImgs(ids[id])[0]
    annos = coco.loadAnns(coco.getAnnIds(ids[id]))
    img = getImg(im['coco_url']).convert("RGB")
    scores, centroids = detect(img, model, transform, det_threshold=det_threshold)
    gt_centroids = estimate_centroids(im, annos)
    plot_results(img, scores, centroids, gt_centroids, [anno['bbox'] for anno in annos], im['file_name'])
    drift_rates = compute_drift_rate(centroids, gt_centroids, [anno['area'] for anno in annos])
    print(f'im: {ids[id]}, drift rates : {drift_rates.cpu().numpy()}')
    val_drift_rates.append(drift_rates)

overall_drit_rates = torch.concat(val_drift_rates, dim=0)

print(f'Average drift rate: {overall_drit_rates.mean()}')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Discussion
# ---
# **write 1 up to 3 sentences for each question**
# 1. ***What is your intution behind your implementation of  coco.py:convert_coco_poly_to_centroids()*** [2 points]
#
#       I am decoding the segmentation predictions into 3D binary masks. Then, I use binary erosion for the thinning parts of the object, focusing only on the bigger, more substantial areas. After that, I calculate the centroids by taking the average position along each axis using the np.mean function. This way, I ensure that the centroid is influenced primarily by the larger and more prominent parts of the object
#
#
# 2. ***Which distance metric have you used for computing the cost matrix between centroids? why?*** [1 points]
#
#   I am using L1 loss to compute the loss between the centroids as L1 is less sensitive to outliers. It measures the absolute differences between the predicted and target centroid values as the magnitude of errors.
# 3. ***Why freezing the entire model and traning just the heads might never actually predict the true centroids?*** [2 points]
#     Freezing parts of the model could skip the crucial spatial details needed for accurate centroid predictions. Centroids rely on where things are in a picture, and the lower layers of the model are adept at understanding this. Centroids are all about position, and these layers excel at figuring that out. Freezing them might make the model struggle with different arrangements. Freezing the whole model, except for the heads, might miss these vital spatial insights. A better approach is letting the model see the whole picture, learn from it, and then fine-tune the details to get really good at predicting centroids. This way, the model can better adapt to finding centroids in different pictures.

# %% [markdown]
# ## Submission guidelines
# ---
#
#
#
# The submission structure should look like:
#
# IMPORTANT: Remove the _checkpoint.pth_ and make sure _heads.pth_ is in the submission.
#
#
# ```
# {last name}_{first name}_{sbu id}_hw2/
# ├── part1/
# │   └── ...
# ├── part2/
# │   ├── CSE527_23F_HW3_P2.ipynb
# │   └── detr/
# │       ├── checkpoints/
# │       │   └── heads.pth
# │       ├── datasets/
# │       │   ├── coco.py
# │       │   ├── ...
# │       │   └── ...
# │       ├── models/
# │       │   ├── detr.py
# │       │   ├── matcher.py
# │       │   ├── ...
# │       │   └── ...
# │       ├── utils/
# │       │   ├── ...
# │       │   └── ...
# │       ├── engine.py
# │       ├── main.py
# │       ├── hubconf.py
# │       └── requirements.txt
# ```
#
#
# Follow instructions in part1's submission guidelines to generate your complete submission
