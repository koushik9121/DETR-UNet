# %% [markdown]
# # CSE527 Homework 3 - Part 3
# **Due date: 23:59 on Nov 26, 2023**
#
#
# ## Description
# ---
# Segmentation has been recently gaining more popularity in the field of computer vision. In this homework you will be implementing a standard UNet model to perform semantic segmentation. While transofrmer based architectures have demostrated impressive perfromance in semantic/instance segmentation, it's important to be familiar with other architectures commonly used for semantic segmentation.
#
# You will use the same dataset that you have used in part 2 of this homework, but the output of the model here is a class level segmentation mask.
#
# Input of the model will be an RGB image (3xHxW) and output will be a boolean mask (HxW).
#
# | Input Image      | Output Mask (class:horse) |
# | ----------- | ----------- |
# | ![Input Image](https://drive.google.com/uc?id=1BqmNxzV4t5MFQHjBFizlI1p9xlEatXiz)| ![Output Image](https://drive.google.com/uc?id=1NCW95D8JDBNsgzfFNa14ZiV_SiCpBPIv)|
#
#
# Read the paper: [U-Net: Convolutional Networks for Biomedical Image Segmentation
# ](https://arxiv.org/abs/1505.04597) to understand the structure of UNet models, what they are composed of, and how to build them.
#
# Also you should refer to this github repo to understand the implementations of a UNet: [milesial/Pytorch-UNet](https://github.com/milesial/Pytorch-UNet) . Specifically refer to unet/unet_model.py to gain understanding of the convolutional blocks, and skip connections.
#
# In this part you will be designing UNet architecture simmilar to it but with specific changes.

# %% [markdown]
# ## Code
# ---

# %%
HW3_ROOT_PATH = '/gdrive/My Drive/' + 'MUPPARAPU_SAIKOUSHIK_114999629_hw3/' #'YOUR HOMEWORK3 PATH HERE'
PATH_TO_PART3 = HW3_ROOT_PATH + 'part3/'
PATH_TO_COCO = HW3_ROOT_PATH + 'coco/'

# %% [markdown]
# You will be using this code [unet.zip](https://drive.google.com/file/d/1p2tMMUfF2vfcr3QHipJx0XyiBOMWoMNM/view?usp=sharing) to complete your work. This code contains all the tools for loading dataset, training the newtorks, loss methods and evaluation metrics.
#
#
# To pull this code into your drive, you have to first add the zip file as shortcut to current working directory (PATH_TO_PART3 above). To do this, open the above link and click on "Add shortcut to Drive" button (drive symbol with a plus) and navigate to working PATH_TO_PART3 directory and add shortcut.
#
#
# We will use the same dataset that you have used in the Part 2 : [coco.zip dataset](https://drive.google.com/file/d/1GVyxYHwVgiG9z_Sn46wslT_2n65DLZRw/view?usp=sharing). Put this in the root of your hw3 HW3_ROOT_PATH. If you have this extracted to some path you can re-use the it.

# %%
from google.colab import drive
drive.mount('/gdrive')
# CD into root of your homework2 part3 directory
# %cd -q $HW3_ROOT_PATH
# !mkdir -p '{PATH_TO_PART3}'
# %cd $PATH_TO_PART3
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/part3

# %%
# !ls
# Out:
# CSE527_23F_HW3_P3.ipynb  unet

# %%
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-crf0b77a
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-crf0b77a
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (67.7.2)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.0.5)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375457 sha256=2fa68431642ff82e80df37330d616bdbc9498d8a581f92ef3d5153263346dfa4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-levy2zix/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# Successfully installed pycocotools-2.0

# %%
# !unzip -n ../coco.zip -d ..
# !unzip -n unet.zip
# Out:
# Archive:  unet.zip
#   inflating: unet/coco.py
#   inflating: unet/main.py
#   inflating: unet/transforms.py
#   inflating: unet/unet.py
#    creating: unet/util/
#  extracting: unet/util/__init__.py
#   inflating: unet/util/box_ops.py
#   inflating: unet/util/misc.py
#   inflating: unet/util/plot_utils.py

# %%
# %cd -q unet
# !ls
# Out:
# coco.py		       images	__pycache__	    transforms.py  util
# concat_checkpoint.pth  main.py	sum_checkpoint.pth  unet.py

# %% [markdown]
# ### Load helper method

# %%
import matplotlib.pyplot as plt
import os
import numpy as np

def show_images(folder_path):
    image_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    image_paths = image_paths[:50]
    rows = 5
    cols = 10
    fig, axes = plt.subplots(rows, cols, figsize=(15, 8))
    for i, image_path in enumerate(image_paths):
        image = plt.imread(image_path)
        row = int(i / cols)
        col = i % cols
        axes[row, col].imshow(image)
        axes[row, col].set_title(os.path.basename(image_path))
        axes[row, col].axis('off')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Training
# ---
# You will use main.py for training, evaluating and visualizing.

# %%
# !python main.py --help
# Out:
# device cuda
# usage: main.py [-h] [--coco_path COCO_PATH] [--batch_size BATCH_SIZE] [--epochs EPOCHS] [--eval]
#                [--load_pretrained] [--skip {concat,sum}] [--checkpoint CHECKPOINT]
#
# Train a segmentation model on COCO data.
#
# options:
#   -h, --help            show this help message and exit
#   --coco_path COCO_PATH
#                         Path to COCO dataset directory.
#   --batch_size BATCH_SIZE
#                         Batch size for training.
#   --epochs EPOCHS       Epochs for training.
#   --eval                Whether to evaluate the model on the validation set.
#   --load_pretrained     Whether to evaluate the model on the validation set.
#   --skip {concat,sum}   Skip connection strategy: either concatenation (concat) or summation
#                         (sum).
#   --checkpoint CHECKPOINT
#                         Path to checkpoint file.

# %% [markdown]
# ##Implement UNet (15 points)
# ---
#
#
# `unet.py` contains two classes `UNet()` and `SumUNet()`, both are implementations of `torch.nn.Module()`.
#
# You need to complete the methods `UNet:__init__()` and `UNet:forward()` to implement a segmentation architecture that processes input of shape `N x 3 x H x W` (N is batch size) and will output a mask of shape `N x 1 x H x W`
#
# ###Requirements
# 1. Encoder part of the UNet will be made of pytorch Resnet's layers 1 to 4.
#
#     https://pytorch.org/vision/main/_modules/torchvision/models/resnet.html
#
#     Essentially, your UNet's encoder will be using `torchvision.models.resnet`'s `layer1, layer2, layer3, layer4` for downsampling.
#
# 2. When argument `load_pretrained_encoder_layers` of __init__() is set to true, the layers will be initialized with the pretrained weights. You can use the default pre-trained weights provided by pytorch.
#
# 3. As described in the paper or above repo, `concatenation` operations will be done for the skip connections. (in the upcoming section, you will instead use summation)
#
#
# Note:
# - You are recommended to size your model under 25M paramenters. As more parameters will hurt the trainig time and even effeciency.
# - For the decoder section (later half), you will not be able to use any pre-trained weights, so you will use randomly initialized blocks (that you will design on your own). Each block usually have layers of `[Conv, BatchNorm, ReLu]`
# - You need not use any ReLU on the last mask output layer.
#
# Hint:
# - chose a [resnet](https://pytorch.org/vision/main/_modules/torchvision/models/resnet.html) size
# - understand the `In` channels & `Out` channels of each layer of your chosen resnet()
# - build decoder layers so that they will work along the above 4 layers
# - conclude how to use the skip connections. ( you will using `concatenation`).
# - complete the forward() method
# - use print(x.shape) statements to understand the flow of tensors
#
# Log reference: [log](https://drive.google.com/file/d/1ZGd-ciOKkajri0GEOwc-uJDBjGJHJdNY/view?usp=drive_link)
#
# Aim for mIoU more than 0.35. You may not be penalized for low perfromance of your model.

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}"
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.47s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:04:00    time: 9.6248  data: 7.0852  max mem: 8653
# Epoch: [0]  [10/25]  eta: 0:01:49    time: 7.2768  data: 6.7816  max mem: 8653
# Epoch: [0]  [20/25]  eta: 0:00:35    time: 6.9158  data: 6.6293  max mem: 8653
# Epoch: [0]  [24/25]  eta: 0:00:07    time: 6.8405  data: 6.5581  max mem: 8653
# Epoch: [0] Total time: 0:02:55 (7.0005 s / it)
# train: dice: 0.835422, bce: 0.547389, loss: 0.642440
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:01    time: 0.5163  data: 0.2557  max mem: 8653
# Epoch: [0]  [2/3]  eta: 0:00:00    time: 0.4015  data: 0.2058  max mem: 8653
# Epoch: [0] Total time: 0:00:01 (0.4019 s / it)
# val: dice: 0.770336, bce: 0.409539, loss: 0.528602, mIoU: 0.000000, mDice: 0.000000
# saving best model to concat_checkpoint.pth
# 2m 56s
# Epoch: [1]  [ 0/25]  eta: 0:00:19    time: 0.7948  data: 0.5655  max mem: 8653
# Epoch: [1]  [10/25]  eta: 0:00:12    time: 0.8611  data: 0.6316  max mem: 8653
# Epoch: [1]  [20/25]  eta: 0:00:04    time: 0.8084  data: 0.5787  max mem: 8653
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.8207  data: 0.5906  max mem: 8653
# Epoch: [1] Total time: 0:00:20 (0.8322 s / it)
# train: dice: 0.780148, bce: 0.365965, loss: 0.502646
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:01    time: 0.6031  data: 0.3781  max mem: 8653
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.4886  data: 0.3041  max mem: 8653
# Epoch: [1] Total time: 0:00:01 (0.4891 s / it)
# val: dice: 0.724615, bce: 0.306220, loss: 0.444290, mIoU: 0.000000, mDice: 0.000000
# saving best model to concat_checkpoint.pth
# 0m 23s
# Epoch: [2]  [ 0/25]  eta: 0:00:27    time: 1.1076  data: 0.8764  max mem: 8653
# Epoch: [2]  [10/25]  eta: 0:00:11    time: 0.7703  data: 0.5390  max mem: 8653
# Epoch: [2]  [20/25]  eta: 0:00:04    time: 0.8257  data: 0.5926  max mem: 8653
# Epoch: [2]  [24/25]  eta: 0:00:00    time: 0.8239  data: 0.5904  max mem: 8653
# Epoch: [2] Total time: 0:00:20 (0.8237 s / it)
# train: dice: 0.736893, bce: 0.337546, loss: 0.469331
# LR 0.0005
# Epoch: [2]  [0/3]  eta: 0:00:01    time: 0.5388  data: 0.2720  max mem: 8653
# Epoch: [2]  [2/3]  eta: 0:00:00    time: 0.4115  data: 0.2117  max mem: 8653
# Epoch: [2] Total time: 0:00:01 (0.4119 s / it)
# val: dice: 0.693922, bce: 0.286363, loss: 0.420858, mIoU: 0.202139, mDice: 0.288320
# saving best model to concat_checkpoint.pth
# 0m 22s
# Epoch: [3]  [ 0/25]  eta: 0:00:18    time: 0.7223  data: 0.4900  max mem: 8653
# Epoch: [3]  [10/25]  eta: 0:00:12    time: 0.8065  data: 0.5714  max mem: 8653
# Epoch: [3]  [20/25]  eta: 0:00:04    time: 0.8316  data: 0.5966  max mem: 8653
# Epoch: [3]  [24/25]  eta: 0:00:00    time: 0.8376  data: 0.6024  max mem: 8653
# Epoch: [3] Total time: 0:00:20 (0.8143 s / it)
# train: dice: 0.724384, bce: 0.337879, loss: 0.465425
# LR 0.0005
# Epoch: [3]  [0/3]  eta: 0:00:01    time: 0.5415  data: 0.2742  max mem: 8653
# Epoch: [3]  [2/3]  eta: 0:00:00    time: 0.4216  data: 0.2201  max mem: 8653
# Epoch: [3] Total time: 0:00:01 (0.4220 s / it)
# val: dice: 0.666992, bce: 0.301882, loss: 0.422368, mIoU: 0.402122, mDice: 0.525263
# 0m 22s
# Epoch: [4]  [ 0/25]  eta: 0:00:18    time: 0.7506  data: 0.5158  max mem: 8653
# Epoch: [4]  [10/25]  eta: 0:00:13    time: 0.8906  data: 0.6562  max mem: 8653
# Epoch: [4]  [20/25]  eta: 0:00:04    time: 0.8158  data: 0.5824  max mem: 8653
# Epoch: [4]  [24/25]  eta: 0:00:00    time: 0.8177  data: 0.5847  max mem: 8653
# Epoch: [4] Total time: 0:00:21 (0.8460 s / it)
# train: dice: 0.705188, bce: 0.337954, loss: 0.459141
# LR 0.0005
# Epoch: [4]  [0/3]  eta: 0:00:01    time: 0.5994  data: 0.3706  max mem: 8653
# Epoch: [4]  [2/3]  eta: 0:00:00    time: 0.4873  data: 0.3000  max mem: 8653
# Epoch: [4] Total time: 0:00:01 (0.4879 s / it)
# val: dice: 0.660824, bce: 0.282082, loss: 0.407067, mIoU: 0.385720, mDice: 0.510648
# saving best model to concat_checkpoint.pth
# 0m 23s
# Epoch: [5]  [ 0/25]  eta: 0:00:23    time: 0.9313  data: 0.6987  max mem: 8653
# Epoch: [5]  [10/25]  eta: 0:00:11    time: 0.7543  data: 0.5219  max mem: 8653
# Epoch: [5]  [20/25]  eta: 0:00:04    time: 0.8266  data: 0.5935  max mem: 8653
# Epoch: [5]  [24/25]  eta: 0:00:00    time: 0.8222  data: 0.5893  max mem: 8653
# Epoch: [5] Total time: 0:00:20 (0.8141 s / it)
# train: dice: 0.703596, bce: 0.321191, loss: 0.447385
# LR 0.0005
# Epoch: [5]  [0/3]  eta: 0:00:01    time: 0.5332  data: 0.2676  max mem: 8653
# Epoch: [5]  [2/3]  eta: 0:00:00    time: 0.4194  data: 0.2195  max mem: 8653
# Epoch: [5] Total time: 0:00:01 (0.4199 s / it)
# val: dice: 0.654579, bce: 0.271913, loss: 0.398193, mIoU: 0.364297, mDice: 0.486680
# saving best model to concat_checkpoint.pth
# 0m 22s
# Epoch: [6]  [ 0/25]  eta: 0:00:20    time: 0.8026  data: 0.5709  max mem: 8653
# Epoch: [6]  [10/25]  eta: 0:00:12    time: 0.8443  data: 0.6117  max mem: 8653
# Epoch: [6]  [20/25]  eta: 0:00:04    time: 0.8300  data: 0.5974  max mem: 8653
# Epoch: [6]  [24/25]  eta: 0:00:00    time: 0.8304  data: 0.5977  max mem: 8653
# Epoch: [6] Total time: 0:00:20 (0.8143 s / it)
# train: dice: 0.679828, bce: 0.320272, loss: 0.438926
# LR 0.0005
# Epoch: [6]  [0/3]  eta: 0:00:01    time: 0.5382  data: 0.2651  max mem: 8653
# Epoch: [6]  [2/3]  eta: 0:00:00    time: 0.4220  data: 0.2197  max mem: 8653
# Epoch: [6] Total time: 0:00:01 (0.4224 s / it)
# val: dice: 0.641188, bce: 0.273606, loss: 0.394908, mIoU: 0.350277, mDice: 0.474915
# saving best model to concat_checkpoint.pth
# 0m 22s
# Epoch: [7]  [ 0/25]  eta: 0:00:29    time: 1.1908  data: 0.9557  max mem: 8653
# Epoch: [7]  [10/25]  eta: 0:00:13    time: 0.8794  data: 0.6454  max mem: 8653
# Epoch: [7]  [20/25]  eta: 0:00:04    time: 0.8280  data: 0.5941  max mem: 8653
# Epoch: [7]  [24/25]  eta: 0:00:00    time: 0.8378  data: 0.6037  max mem: 8653
# Epoch: [7] Total time: 0:00:21 (0.8734 s / it)
# train: dice: 0.654762, bce: 0.308209, loss: 0.422572
# LR 0.0005
# Epoch: [7]  [0/3]  eta: 0:00:01    time: 0.6030  data: 0.3724  max mem: 8653
# Epoch: [7]  [2/3]  eta: 0:00:00    time: 0.4464  data: 0.2586  max mem: 8653
# Epoch: [7] Total time: 0:00:01 (0.4468 s / it)
# val: dice: 0.619825, bce: 0.269572, loss: 0.385155, mIoU: 0.399515, mDice: 0.525248
# saving best model to concat_checkpoint.pth
# 0m 23s
# Epoch: [8]  [ 0/25]  eta: 0:00:20    time: 0.8217  data: 0.5888  max mem: 8653
# Epoch: [8]  [10/25]  eta: 0:00:11    time: 0.7554  data: 0.5223  max mem: 8653
# Epoch: [8]  [20/25]  eta: 0:00:04    time: 0.8354  data: 0.6022  max mem: 8653
# Epoch: [8]  [24/25]  eta: 0:00:00    time: 0.8263  data: 0.5935  max mem: 8653
# Epoch: [8] Total time: 0:00:20 (0.8172 s / it)
# train: dice: 0.649083, bce: 0.312392, loss: 0.423500
# LR 0.0005
# Epoch: [8]  [0/3]  eta: 0:00:01    time: 0.5355  data: 0.2685  max mem: 8653
# Epoch: [8]  [2/3]  eta: 0:00:00    time: 0.4101  data: 0.2101  max mem: 8653
# Epoch: [8] Total time: 0:00:01 (0.4105 s / it)
# val: dice: 0.595471, bce: 0.283819, loss: 0.386664, mIoU: 0.429479, mDice: 0.553120
# 0m 22s
# Epoch: [9]  [ 0/25]  eta: 0:00:18    time: 0.7266  data: 0.4953  max mem: 8653
# Epoch: [9]  [10/25]  eta: 0:00:12    time: 0.8649  data: 0.6313  max mem: 8653
# Epoch: [9]  [20/25]  eta: 0:00:04    time: 0.8111  data: 0.5783  max mem: 8653
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.8095  data: 0.5769  max mem: 8653
# Epoch: [9] Total time: 0:00:19 (0.7932 s / it)
# train: dice: 0.667130, bce: 0.325382, loss: 0.438159
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:01    time: 0.5825  data: 0.3559  max mem: 8653
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.4808  data: 0.2946  max mem: 8653
# Epoch: [9] Total time: 0:00:01 (0.4813 s / it)
# val: dice: 0.628693, bce: 0.268452, loss: 0.387331, mIoU: 0.382845, mDice: 0.510178
# 0m 21s
# Epoch: [10]  [ 0/25]  eta: 0:00:26    time: 1.0590  data: 0.8259  max mem: 8653
# Epoch: [10]  [10/25]  eta: 0:00:12    time: 0.8321  data: 0.5993  max mem: 8653
# Epoch: [10]  [20/25]  eta: 0:00:04    time: 0.7903  data: 0.5576  max mem: 8653
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.7967  data: 0.5641  max mem: 8653
# Epoch: [10] Total time: 0:00:20 (0.8354 s / it)
# train: dice: 0.647886, bce: 0.307688, loss: 0.419953
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:01    time: 0.5981  data: 0.3699  max mem: 8653
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.4308  data: 0.2436  max mem: 8653
# Epoch: [10] Total time: 0:00:01 (0.4312 s / it)
# val: dice: 0.625130, bce: 0.277927, loss: 0.392504, mIoU: 0.330989, mDice: 0.453751
# 0m 22s
# Epoch: [11]  [ 0/25]  eta: 0:00:17    time: 0.6858  data: 0.4541  max mem: 8653
# Epoch: [11]  [10/25]  eta: 0:00:10    time: 0.7118  data: 0.4791  max mem: 8653
# Epoch: [11]  [20/25]  eta: 0:00:04    time: 0.8074  data: 0.5738  max mem: 8653
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.8010  data: 0.5676  max mem: 8653
# Epoch: [11] Total time: 0:00:19 (0.7855 s / it)
# train: dice: 0.626991, bce: 0.300854, loss: 0.408480
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:01    time: 0.5383  data: 0.2755  max mem: 8653
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.4141  data: 0.2154  max mem: 8653
# Epoch: [11] Total time: 0:00:01 (0.4145 s / it)
# val: dice: 0.601007, bce: 0.260540, loss: 0.372894, mIoU: 0.381541, mDice: 0.509587
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [12]  [ 0/25]  eta: 0:00:18    time: 0.7428  data: 0.5109  max mem: 8653
# Epoch: [12]  [10/25]  eta: 0:00:12    time: 0.8600  data: 0.6270  max mem: 8653
# Epoch: [12]  [20/25]  eta: 0:00:04    time: 0.8179  data: 0.5846  max mem: 8653
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.8154  data: 0.5821  max mem: 8653
# Epoch: [12] Total time: 0:00:19 (0.7984 s / it)
# train: dice: 0.644097, bce: 0.310367, loss: 0.420498
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:01    time: 0.5359  data: 0.2933  max mem: 8653
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.4618  data: 0.2700  max mem: 8653
# Epoch: [12] Total time: 0:00:01 (0.4623 s / it)
# val: dice: 0.607338, bce: 0.275157, loss: 0.384777, mIoU: 0.419415, mDice: 0.547080
# 0m 21s
# Epoch: [13]  [ 0/25]  eta: 0:00:25    time: 1.0166  data: 0.7844  max mem: 8653
# Epoch: [13]  [10/25]  eta: 0:00:13    time: 0.8716  data: 0.6382  max mem: 8653
# Epoch: [13]  [20/25]  eta: 0:00:04    time: 0.8208  data: 0.5877  max mem: 8653
# Epoch: [13]  [24/25]  eta: 0:00:00    time: 0.8157  data: 0.5827  max mem: 8653
# Epoch: [13] Total time: 0:00:21 (0.8553 s / it)
# train: dice: 0.634272, bce: 0.307563, loss: 0.415377
# LR 0.0005
# Epoch: [13]  [0/3]  eta: 0:00:01    time: 0.5894  data: 0.3623  max mem: 8653
# Epoch: [13]  [2/3]  eta: 0:00:00    time: 0.4260  data: 0.2396  max mem: 8653
# Epoch: [13] Total time: 0:00:01 (0.4264 s / it)
# val: dice: 0.630111, bce: 0.272615, loss: 0.390589, mIoU: 0.318904, mDice: 0.441913
# 0m 23s
# Epoch: [14]  [ 0/25]  eta: 0:00:19    time: 0.7724  data: 0.5385  max mem: 8653
# Epoch: [14]  [10/25]  eta: 0:00:10    time: 0.7167  data: 0.4839  max mem: 8653
# Epoch: [14]  [20/25]  eta: 0:00:03    time: 0.7992  data: 0.5660  max mem: 8653
# Epoch: [14]  [24/25]  eta: 0:00:00    time: 0.8020  data: 0.5688  max mem: 8653
# Epoch: [14] Total time: 0:00:19 (0.7871 s / it)
# train: dice: 0.619065, bce: 0.300101, loss: 0.405359
# LR 0.0005
# Epoch: [14]  [0/3]  eta: 0:00:01    time: 0.5349  data: 0.2723  max mem: 8653
# Epoch: [14]  [2/3]  eta: 0:00:00    time: 0.4142  data: 0.2156  max mem: 8653
# Epoch: [14] Total time: 0:00:01 (0.4146 s / it)
# val: dice: 0.636733, bce: 0.272792, loss: 0.392893, mIoU: 0.290776, mDice: 0.408298
# 0m 21s
# Epoch: [15]  [ 0/25]  eta: 0:00:18    time: 0.7413  data: 0.5090  max mem: 8653
# Epoch: [15]  [10/25]  eta: 0:00:12    time: 0.8279  data: 0.5948  max mem: 8653
# Epoch: [15]  [20/25]  eta: 0:00:04    time: 0.8035  data: 0.5705  max mem: 8653
# Epoch: [15]  [24/25]  eta: 0:00:00    time: 0.8028  data: 0.5697  max mem: 8653
# Epoch: [15] Total time: 0:00:19 (0.7874 s / it)
# train: dice: 0.611261, bce: 0.290143, loss: 0.396112
# LR 0.0005
# Epoch: [15]  [0/3]  eta: 0:00:01    time: 0.5387  data: 0.2756  max mem: 8653
# Epoch: [15]  [2/3]  eta: 0:00:00    time: 0.4270  data: 0.2274  max mem: 8653
# Epoch: [15] Total time: 0:00:01 (0.4274 s / it)
# val: dice: 0.596064, bce: 0.262723, loss: 0.372725, mIoU: 0.367718, mDice: 0.495412
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [16]  [ 0/25]  eta: 0:00:25    time: 1.0007  data: 0.7677  max mem: 8653
# Epoch: [16]  [10/25]  eta: 0:00:12    time: 0.8657  data: 0.6321  max mem: 8653
# Epoch: [16]  [20/25]  eta: 0:00:04    time: 0.8241  data: 0.5905  max mem: 8653
# Epoch: [16]  [24/25]  eta: 0:00:00    time: 0.8287  data: 0.5953  max mem: 8653
# Epoch: [16] Total time: 0:00:21 (0.8618 s / it)
# train: dice: 0.615790, bce: 0.294497, loss: 0.400524
# LR 0.0005
# Epoch: [16]  [0/3]  eta: 0:00:01    time: 0.5982  data: 0.3694  max mem: 8653
# Epoch: [16]  [2/3]  eta: 0:00:00    time: 0.4289  data: 0.2423  max mem: 8653
# Epoch: [16] Total time: 0:00:01 (0.4294 s / it)
# val: dice: 0.595649, bce: 0.261978, loss: 0.372089, mIoU: 0.357414, mDice: 0.482722
# saving best model to concat_checkpoint.pth
# 0m 23s
# Epoch: [17]  [ 0/25]  eta: 0:00:19    time: 0.7743  data: 0.5413  max mem: 8653
# Epoch: [17]  [10/25]  eta: 0:00:10    time: 0.7223  data: 0.4899  max mem: 8653
# Epoch: [17]  [20/25]  eta: 0:00:04    time: 0.8118  data: 0.5790  max mem: 8653
# Epoch: [17]  [24/25]  eta: 0:00:00    time: 0.8138  data: 0.5810  max mem: 8653
# Epoch: [17] Total time: 0:00:19 (0.7968 s / it)
# train: dice: 0.603531, bce: 0.293073, loss: 0.395524
# LR 0.0005
# Epoch: [17]  [0/3]  eta: 0:00:01    time: 0.5359  data: 0.2632  max mem: 8653
# Epoch: [17]  [2/3]  eta: 0:00:00    time: 0.4141  data: 0.2126  max mem: 8653
# Epoch: [17] Total time: 0:00:01 (0.4145 s / it)
# val: dice: 0.594737, bce: 0.271765, loss: 0.378346, mIoU: 0.344809, mDice: 0.471617
# 0m 21s
# Epoch: [18]  [ 0/25]  eta: 0:00:17    time: 0.7156  data: 0.4846  max mem: 8653
# Epoch: [18]  [10/25]  eta: 0:00:12    time: 0.8547  data: 0.6215  max mem: 8653
# Epoch: [18]  [20/25]  eta: 0:00:04    time: 0.8139  data: 0.5806  max mem: 8653
# Epoch: [18]  [24/25]  eta: 0:00:00    time: 0.8116  data: 0.5784  max mem: 8653
# Epoch: [18] Total time: 0:00:19 (0.7940 s / it)
# train: dice: 0.600145, bce: 0.293461, loss: 0.394666
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:01    time: 0.5370  data: 0.2715  max mem: 8653
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.4557  data: 0.2558  max mem: 8653
# Epoch: [18] Total time: 0:00:01 (0.4562 s / it)
# val: dice: 0.670884, bce: 0.285520, loss: 0.412690, mIoU: 0.205765, mDice: 0.306014
# 0m 21s
# Epoch: [19]  [ 0/25]  eta: 0:00:24    time: 0.9749  data: 0.7420  max mem: 8653
# Epoch: [19]  [10/25]  eta: 0:00:12    time: 0.8634  data: 0.6300  max mem: 8653
# Epoch: [19]  [20/25]  eta: 0:00:04    time: 0.8105  data: 0.5771  max mem: 8653
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.8010  data: 0.5677  max mem: 8653
# Epoch: [19] Total time: 0:00:20 (0.8397 s / it)
# train: dice: 0.594947, bce: 0.279273, loss: 0.383445
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.5925  data: 0.3627  max mem: 8653
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.4325  data: 0.2448  max mem: 8653
# Epoch: [19] Total time: 0:00:01 (0.4329 s / it)
# val: dice: 0.623514, bce: 0.266001, loss: 0.383980, mIoU: 0.304741, mDice: 0.426915
# 0m 22s
# Best val loss: 0.372089

# %% [markdown]
# ### Evaluation
# To just run the evaluation or to produce the predicted masks in the `images/` folder, you need to run the main.py with --eval.
# Note that this will load the latest stored checkpoint corresponding to the --skip flag that you have provided.

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}" --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.3574138581752777 , mDice:0.48272210359573364

# %% [markdown]
# ### With --load_pretrained
#
# When properly configured using pre-trained weights should result in higher mIoUs. You can expect mIoU around .65

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}"  --load_pretrained
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=True, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 48.8MB/s]
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:00:57    time: 2.2866  data: 0.4646  max mem: 8653
# Epoch: [0]  [10/25]  eta: 0:00:15    time: 1.0225  data: 0.6469  max mem: 8653
# Epoch: [0]  [20/25]  eta: 0:00:04    time: 0.8059  data: 0.5774  max mem: 8653
# Epoch: [0]  [24/25]  eta: 0:00:00    time: 0.7975  data: 0.5708  max mem: 8653
# Epoch: [0] Total time: 0:00:21 (0.8708 s / it)
# train: dice: 0.833411, bce: 0.516408, loss: 0.621019
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:01    time: 0.5859  data: 0.3604  max mem: 8653
# Epoch: [0]  [2/3]  eta: 0:00:00    time: 0.4755  data: 0.2851  max mem: 8653
# Epoch: [0] Total time: 0:00:01 (0.4760 s / it)
# val: dice: 0.768784, bce: 0.380199, loss: 0.508432, mIoU: 0.000000, mDice: 0.000000
# saving best model to concat_checkpoint.pth
# 0m 23s
# Epoch: [1]  [ 0/25]  eta: 0:00:25    time: 1.0270  data: 0.7993  max mem: 8653
# Epoch: [1]  [10/25]  eta: 0:00:11    time: 0.7754  data: 0.5476  max mem: 8653
# Epoch: [1]  [20/25]  eta: 0:00:04    time: 0.8007  data: 0.5717  max mem: 8653
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.8108  data: 0.5813  max mem: 8653
# Epoch: [1] Total time: 0:00:20 (0.8219 s / it)
# train: dice: 0.690909, bce: 0.272192, loss: 0.410368
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:01    time: 0.5258  data: 0.2705  max mem: 8653
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.4033  data: 0.2088  max mem: 8653
# Epoch: [1] Total time: 0:00:01 (0.4037 s / it)
# val: dice: 0.584952, bce: 0.199369, loss: 0.326611, mIoU: 0.502087, mDice: 0.615648
# saving best model to concat_checkpoint.pth
# 0m 22s
# Epoch: [2]  [ 0/25]  eta: 0:00:19    time: 0.7941  data: 0.5669  max mem: 8653
# Epoch: [2]  [10/25]  eta: 0:00:11    time: 0.7491  data: 0.5181  max mem: 8653
# Epoch: [2]  [20/25]  eta: 0:00:04    time: 0.8114  data: 0.5792  max mem: 8653
# Epoch: [2]  [24/25]  eta: 0:00:00    time: 0.8150  data: 0.5821  max mem: 8653
# Epoch: [2] Total time: 0:00:19 (0.7987 s / it)
# train: dice: 0.509028, bce: 0.202437, loss: 0.303612
# LR 0.0005
# Epoch: [2]  [0/3]  eta: 0:00:01    time: 0.5386  data: 0.2590  max mem: 8653
# Epoch: [2]  [2/3]  eta: 0:00:00    time: 0.4150  data: 0.2102  max mem: 8653
# Epoch: [2] Total time: 0:00:01 (0.4154 s / it)
# val: dice: 0.402583, bce: 0.177858, loss: 0.252017, mIoU: 0.577873, mDice: 0.696879
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [3]  [ 0/25]  eta: 0:00:17    time: 0.7144  data: 0.4797  max mem: 8653
# Epoch: [3]  [10/25]  eta: 0:00:13    time: 0.8678  data: 0.6320  max mem: 8653
# Epoch: [3]  [20/25]  eta: 0:00:04    time: 0.8105  data: 0.5755  max mem: 8653
# Epoch: [3]  [24/25]  eta: 0:00:00    time: 0.8096  data: 0.5751  max mem: 8653
# Epoch: [3] Total time: 0:00:20 (0.8165 s / it)
# train: dice: 0.414740, bce: 0.172342, loss: 0.252333
# LR 0.0005
# Epoch: [3]  [0/3]  eta: 0:00:01    time: 0.6067  data: 0.3765  max mem: 8653
# Epoch: [3]  [2/3]  eta: 0:00:00    time: 0.4948  data: 0.3071  max mem: 8653
# Epoch: [3] Total time: 0:00:01 (0.4953 s / it)
# val: dice: 0.440280, bce: 0.188658, loss: 0.271693, mIoU: 0.507566, mDice: 0.614012
# 0m 22s
# Epoch: [4]  [ 0/25]  eta: 0:00:23    time: 0.9512  data: 0.7164  max mem: 8653
# Epoch: [4]  [10/25]  eta: 0:00:11    time: 0.7775  data: 0.5443  max mem: 8653
# Epoch: [4]  [20/25]  eta: 0:00:04    time: 0.7941  data: 0.5609  max mem: 8653
# Epoch: [4]  [24/25]  eta: 0:00:00    time: 0.8017  data: 0.5687  max mem: 8653
# Epoch: [4] Total time: 0:00:20 (0.8110 s / it)
# train: dice: 0.387960, bce: 0.163911, loss: 0.237847
# LR 0.0005
# Epoch: [4]  [0/3]  eta: 0:00:01    time: 0.5330  data: 0.2687  max mem: 8653
# Epoch: [4]  [2/3]  eta: 0:00:00    time: 0.4073  data: 0.2083  max mem: 8653
# Epoch: [4] Total time: 0:00:01 (0.4077 s / it)
# val: dice: 0.389410, bce: 0.159393, loss: 0.235298, mIoU: 0.572454, mDice: 0.681052
# saving best model to concat_checkpoint.pth
# 0m 22s
# Epoch: [5]  [ 0/25]  eta: 0:00:18    time: 0.7352  data: 0.5026  max mem: 8653
# Epoch: [5]  [10/25]  eta: 0:00:11    time: 0.7374  data: 0.5054  max mem: 8653
# Epoch: [5]  [20/25]  eta: 0:00:04    time: 0.8045  data: 0.5715  max mem: 8653
# Epoch: [5]  [24/25]  eta: 0:00:00    time: 0.8079  data: 0.5747  max mem: 8653
# Epoch: [5] Total time: 0:00:19 (0.7895 s / it)
# train: dice: 0.367072, bce: 0.150467, loss: 0.221947
# LR 0.0005
# Epoch: [5]  [0/3]  eta: 0:00:01    time: 0.5345  data: 0.2664  max mem: 8653
# Epoch: [5]  [2/3]  eta: 0:00:00    time: 0.4149  data: 0.2148  max mem: 8653
# Epoch: [5] Total time: 0:00:01 (0.4152 s / it)
# val: dice: 0.389397, bce: 0.157865, loss: 0.234271, mIoU: 0.578694, mDice: 0.684676
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [6]  [ 0/25]  eta: 0:00:18    time: 0.7597  data: 0.5287  max mem: 8653
# Epoch: [6]  [10/25]  eta: 0:00:13    time: 0.8798  data: 0.6462  max mem: 8653
# Epoch: [6]  [20/25]  eta: 0:00:04    time: 0.8171  data: 0.5838  max mem: 8653
# Epoch: [6]  [24/25]  eta: 0:00:00    time: 0.8185  data: 0.5852  max mem: 8653
# Epoch: [6] Total time: 0:00:20 (0.8196 s / it)
# train: dice: 0.352214, bce: 0.143583, loss: 0.212431
# LR 0.0005
# Epoch: [6]  [0/3]  eta: 0:00:01    time: 0.5992  data: 0.3684  max mem: 8653
# Epoch: [6]  [2/3]  eta: 0:00:00    time: 0.4779  data: 0.2899  max mem: 8653
# Epoch: [6] Total time: 0:00:01 (0.4784 s / it)
# val: dice: 0.376807, bce: 0.151499, loss: 0.225851, mIoU: 0.606336, mDice: 0.708489
# saving best model to concat_checkpoint.pth
# 0m 22s
# Epoch: [7]  [ 0/25]  eta: 0:00:26    time: 1.0765  data: 0.8424  max mem: 8653
# Epoch: [7]  [10/25]  eta: 0:00:11    time: 0.7903  data: 0.5576  max mem: 8653
# Epoch: [7]  [20/25]  eta: 0:00:04    time: 0.8134  data: 0.5801  max mem: 8653
# Epoch: [7]  [24/25]  eta: 0:00:00    time: 0.8145  data: 0.5812  max mem: 8653
# Epoch: [7] Total time: 0:00:20 (0.8231 s / it)
# train: dice: 0.337270, bce: 0.130967, loss: 0.199047
# LR 0.0005
# Epoch: [7]  [0/3]  eta: 0:00:01    time: 0.5344  data: 0.2579  max mem: 8653
# Epoch: [7]  [2/3]  eta: 0:00:00    time: 0.4069  data: 0.2041  max mem: 8653
# Epoch: [7] Total time: 0:00:01 (0.4073 s / it)
# val: dice: 0.358557, bce: 0.168438, loss: 0.231178, mIoU: 0.604604, mDice: 0.707101
# 0m 22s
# Epoch: [8]  [ 0/25]  eta: 0:00:18    time: 0.7572  data: 0.5249  max mem: 8653
# Epoch: [8]  [10/25]  eta: 0:00:11    time: 0.7555  data: 0.5226  max mem: 8653
# Epoch: [8]  [20/25]  eta: 0:00:04    time: 0.8073  data: 0.5739  max mem: 8653
# Epoch: [8]  [24/25]  eta: 0:00:00    time: 0.8047  data: 0.5714  max mem: 8653
# Epoch: [8] Total time: 0:00:19 (0.7910 s / it)
# train: dice: 0.325121, bce: 0.133808, loss: 0.196942
# LR 0.0005
# Epoch: [8]  [0/3]  eta: 0:00:01    time: 0.5333  data: 0.2601  max mem: 8653
# Epoch: [8]  [2/3]  eta: 0:00:00    time: 0.4112  data: 0.2085  max mem: 8653
# Epoch: [8] Total time: 0:00:01 (0.4116 s / it)
# val: dice: 0.362019, bce: 0.150274, loss: 0.220150, mIoU: 0.607270, mDice: 0.709583
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [9]  [ 0/25]  eta: 0:00:18    time: 0.7449  data: 0.5118  max mem: 8653
# Epoch: [9]  [10/25]  eta: 0:00:12    time: 0.8639  data: 0.6304  max mem: 8653
# Epoch: [9]  [20/25]  eta: 0:00:04    time: 0.8061  data: 0.5728  max mem: 8653
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.7993  data: 0.5659  max mem: 8653
# Epoch: [9] Total time: 0:00:20 (0.8086 s / it)
# train: dice: 0.326062, bce: 0.131203, loss: 0.195506
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:01    time: 0.5909  data: 0.3615  max mem: 8653
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.4825  data: 0.2937  max mem: 8653
# Epoch: [9] Total time: 0:00:01 (0.4830 s / it)
# val: dice: 0.373205, bce: 0.155798, loss: 0.227542, mIoU: 0.593475, mDice: 0.699317
# 0m 22s
# Epoch: [10]  [ 0/25]  eta: 0:00:26    time: 1.0511  data: 0.8150  max mem: 8653
# Epoch: [10]  [10/25]  eta: 0:00:11    time: 0.7839  data: 0.5510  max mem: 8653
# Epoch: [10]  [20/25]  eta: 0:00:03    time: 0.7784  data: 0.5452  max mem: 8653
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.7839  data: 0.5506  max mem: 8653
# Epoch: [10] Total time: 0:00:20 (0.8037 s / it)
# train: dice: 0.318896, bce: 0.128483, loss: 0.191319
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:01    time: 0.5373  data: 0.2615  max mem: 8653
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.4105  data: 0.2076  max mem: 8653
# Epoch: [10] Total time: 0:00:01 (0.4109 s / it)
# val: dice: 0.370878, bce: 0.175704, loss: 0.240112, mIoU: 0.593797, mDice: 0.698406
# 0m 21s
# Epoch: [11]  [ 0/25]  eta: 0:00:17    time: 0.7028  data: 0.4704  max mem: 8653
# Epoch: [11]  [10/25]  eta: 0:00:10    time: 0.7081  data: 0.4751  max mem: 8653
# Epoch: [11]  [20/25]  eta: 0:00:03    time: 0.8026  data: 0.5694  max mem: 8653
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.8022  data: 0.5692  max mem: 8653
# Epoch: [11] Total time: 0:00:19 (0.7837 s / it)
# train: dice: 0.306918, bce: 0.124353, loss: 0.184600
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:01    time: 0.5386  data: 0.2596  max mem: 8653
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.4094  data: 0.2059  max mem: 8653
# Epoch: [11] Total time: 0:00:01 (0.4097 s / it)
# val: dice: 0.364359, bce: 0.153601, loss: 0.223151, mIoU: 0.602403, mDice: 0.704697
# 0m 21s
# Epoch: [12]  [ 0/25]  eta: 0:00:17    time: 0.7044  data: 0.4720  max mem: 8653
# Epoch: [12]  [10/25]  eta: 0:00:13    time: 0.8681  data: 0.6345  max mem: 8653
# Epoch: [12]  [20/25]  eta: 0:00:03    time: 0.8037  data: 0.5705  max mem: 8653
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.8030  data: 0.5694  max mem: 8653
# Epoch: [12] Total time: 0:00:19 (0.7918 s / it)
# train: dice: 0.320869, bce: 0.128586, loss: 0.192039
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:01    time: 0.6233  data: 0.3914  max mem: 8653
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.4962  data: 0.3069  max mem: 8653
# Epoch: [12] Total time: 0:00:01 (0.4967 s / it)
# val: dice: 0.400988, bce: 0.169695, loss: 0.246022, mIoU: 0.555399, mDice: 0.667260
# 0m 21s
# Epoch: [13]  [ 0/25]  eta: 0:00:24    time: 0.9631  data: 0.7251  max mem: 8653
# Epoch: [13]  [10/25]  eta: 0:00:12    time: 0.8264  data: 0.5928  max mem: 8653
# Epoch: [13]  [20/25]  eta: 0:00:04    time: 0.8031  data: 0.5699  max mem: 8653
# Epoch: [13]  [24/25]  eta: 0:00:00    time: 0.8046  data: 0.5711  max mem: 8653
# Epoch: [13] Total time: 0:00:20 (0.8341 s / it)
# train: dice: 0.313840, bce: 0.121869, loss: 0.185219
# LR 0.0005
# Epoch: [13]  [0/3]  eta: 0:00:01    time: 0.5332  data: 0.2735  max mem: 8653
# Epoch: [13]  [2/3]  eta: 0:00:00    time: 0.4096  data: 0.2114  max mem: 8653
# Epoch: [13] Total time: 0:00:01 (0.4100 s / it)
# val: dice: 0.342067, bce: 0.161139, loss: 0.220845, mIoU: 0.619776, mDice: 0.720228
# 0m 22s
# Epoch: [14]  [ 0/25]  eta: 0:00:19    time: 0.7702  data: 0.5379  max mem: 8653
# Epoch: [14]  [10/25]  eta: 0:00:10    time: 0.7137  data: 0.4814  max mem: 8653
# Epoch: [14]  [20/25]  eta: 0:00:03    time: 0.7959  data: 0.5633  max mem: 8653
# Epoch: [14]  [24/25]  eta: 0:00:00    time: 0.7970  data: 0.5645  max mem: 8653
# Epoch: [14] Total time: 0:00:19 (0.7822 s / it)
# train: dice: 0.289686, bce: 0.112150, loss: 0.170737
# LR 0.0005
# Epoch: [14]  [0/3]  eta: 0:00:01    time: 0.5357  data: 0.2572  max mem: 8653
# Epoch: [14]  [2/3]  eta: 0:00:00    time: 0.4065  data: 0.2029  max mem: 8653
# Epoch: [14] Total time: 0:00:01 (0.4069 s / it)
# val: dice: 0.353829, bce: 0.159317, loss: 0.223506, mIoU: 0.603627, mDice: 0.707825
# 0m 21s
# Epoch: [15]  [ 0/25]  eta: 0:00:17    time: 0.7169  data: 0.4863  max mem: 8653
# Epoch: [15]  [10/25]  eta: 0:00:12    time: 0.8327  data: 0.5996  max mem: 8653
# Epoch: [15]  [20/25]  eta: 0:00:04    time: 0.8049  data: 0.5718  max mem: 8653
# Epoch: [15]  [24/25]  eta: 0:00:00    time: 0.8039  data: 0.5706  max mem: 8653
# Epoch: [15] Total time: 0:00:19 (0.7861 s / it)
# train: dice: 0.282483, bce: 0.109676, loss: 0.166703
# LR 0.0005
# Epoch: [15]  [0/3]  eta: 0:00:01    time: 0.5375  data: 0.2619  max mem: 8653
# Epoch: [15]  [2/3]  eta: 0:00:00    time: 0.4574  data: 0.2539  max mem: 8653
# Epoch: [15] Total time: 0:00:01 (0.4579 s / it)
# val: dice: 0.348036, bce: 0.149199, loss: 0.214815, mIoU: 0.621109, mDice: 0.720632
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [16]  [ 0/25]  eta: 0:00:24    time: 0.9957  data: 0.7622  max mem: 8653
# Epoch: [16]  [10/25]  eta: 0:00:12    time: 0.8340  data: 0.6007  max mem: 8653
# Epoch: [16]  [20/25]  eta: 0:00:04    time: 0.8042  data: 0.5705  max mem: 8653
# Epoch: [16]  [24/25]  eta: 0:00:00    time: 0.8082  data: 0.5745  max mem: 8653
# Epoch: [16] Total time: 0:00:21 (0.8419 s / it)
# train: dice: 0.286958, bce: 0.114647, loss: 0.171510
# LR 0.0005
# Epoch: [16]  [0/3]  eta: 0:00:01    time: 0.5654  data: 0.3376  max mem: 8653
# Epoch: [16]  [2/3]  eta: 0:00:00    time: 0.4206  data: 0.2331  max mem: 8653
# Epoch: [16] Total time: 0:00:01 (0.4210 s / it)
# val: dice: 0.345695, bce: 0.146902, loss: 0.212504, mIoU: 0.624610, mDice: 0.722447
# saving best model to concat_checkpoint.pth
# 0m 23s
# Epoch: [17]  [ 0/25]  eta: 0:00:19    time: 0.7885  data: 0.5549  max mem: 8653
# Epoch: [17]  [10/25]  eta: 0:00:10    time: 0.7216  data: 0.4888  max mem: 8653
# Epoch: [17]  [20/25]  eta: 0:00:04    time: 0.8069  data: 0.5736  max mem: 8653
# Epoch: [17]  [24/25]  eta: 0:00:00    time: 0.8069  data: 0.5734  max mem: 8653
# Epoch: [17] Total time: 0:00:19 (0.7927 s / it)
# train: dice: 0.276202, bce: 0.108592, loss: 0.163903
# LR 0.0005
# Epoch: [17]  [0/3]  eta: 0:00:01    time: 0.5388  data: 0.2721  max mem: 8653
# Epoch: [17]  [2/3]  eta: 0:00:00    time: 0.4127  data: 0.2130  max mem: 8653
# Epoch: [17] Total time: 0:00:01 (0.4131 s / it)
# val: dice: 0.345115, bce: 0.156257, loss: 0.218580, mIoU: 0.621203, mDice: 0.719949
# 0m 21s
# Epoch: [18]  [ 0/25]  eta: 0:00:17    time: 0.7164  data: 0.4845  max mem: 8653
# Epoch: [18]  [10/25]  eta: 0:00:12    time: 0.8365  data: 0.6027  max mem: 8653
# Epoch: [18]  [20/25]  eta: 0:00:03    time: 0.7986  data: 0.5653  max mem: 8653
# Epoch: [18]  [24/25]  eta: 0:00:00    time: 0.7981  data: 0.5647  max mem: 8653
# Epoch: [18] Total time: 0:00:19 (0.7811 s / it)
# train: dice: 0.267612, bce: 0.105059, loss: 0.158702
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:01    time: 0.5346  data: 0.2633  max mem: 8653
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.4292  data: 0.2263  max mem: 8653
# Epoch: [18] Total time: 0:00:01 (0.4296 s / it)
# val: dice: 0.323208, bce: 0.157307, loss: 0.212054, mIoU: 0.640323, mDice: 0.738151
# saving best model to concat_checkpoint.pth
# 0m 21s
# Epoch: [19]  [ 0/25]  eta: 0:00:25    time: 1.0144  data: 0.7828  max mem: 8653
# Epoch: [19]  [10/25]  eta: 0:00:12    time: 0.8639  data: 0.6307  max mem: 8653
# Epoch: [19]  [20/25]  eta: 0:00:04    time: 0.8144  data: 0.5808  max mem: 8653
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.8087  data: 0.5752  max mem: 8653
# Epoch: [19] Total time: 0:00:21 (0.8437 s / it)
# train: dice: 0.273031, bce: 0.108386, loss: 0.162719
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.5957  data: 0.3656  max mem: 8653
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.4415  data: 0.2535  max mem: 8653
# Epoch: [19] Total time: 0:00:01 (0.4420 s / it)
# val: dice: 0.339792, bce: 0.158289, loss: 0.218185, mIoU: 0.615921, mDice: 0.716757
# 0m 22s
# Best val loss: 0.212054

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}" --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.6403228640556335 , mDice:0.738150954246521

# %% [markdown]
# Let us see the masks generated by the best run:
# It is okay if the masks are not perfectly aligned. We are only training over 500 images for a short duration!

# %%
folder_path = 'images'
show_images(folder_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##Implement SumUNet (10 points)
# ---
# This is very much similar to above UNet, but for the skip connections we will be using summation operation instead of concatenation. This is kind of an open ended question, in the sense that there are multuple ways you can design connections.
#
# Feel free to use any layers | blocks | up/down sampling.
#
#
# Hint:
# - Again you need to focus on the feature shapes
# - you can use sampling techniques to change the height/width
# - you can use conv layers to change number of channels
#
# Note: You can chose to remove --load_pretrained from the below cell if you think that will have a better perfromance

# %%
# !python main.py --skip sum --coco_path "{PATH_TO_COCO}"  --load_pretrained
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=True, skip='sum', checkpoint='sum_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:00:56    time: 2.2551  data: 0.4828  max mem: 2802
# Epoch: [0]  [10/25]  eta: 0:00:11    time: 0.7728  data: 0.4922  max mem: 3178
# Epoch: [0]  [20/25]  eta: 0:00:03    time: 0.7183  data: 0.5839  max mem: 3178
# Epoch: [0]  [24/25]  eta: 0:00:00    time: 0.7152  data: 0.5798  max mem: 3178
# Epoch: [0] Total time: 0:00:19 (0.7650 s / it)
# train: dice: 0.720119, bce: 0.453359, loss: 0.541390
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:01    time: 0.3808  data: 0.2667  max mem: 3178
# Epoch: [0]  [2/3]  eta: 0:00:00    time: 0.3087  data: 0.2106  max mem: 3178
# Epoch: [0] Total time: 0:00:00 (0.3091 s / it)
# val: dice: 0.510733, bce: 0.244082, loss: 0.332077, mIoU: 0.466683, mDice: 0.583329
# saving best model to sum_checkpoint.pth
# 0m 21s
# Epoch: [1]  [ 0/25]  eta: 0:00:15    time: 0.6171  data: 0.4832  max mem: 3178
# Epoch: [1]  [10/25]  eta: 0:00:10    time: 0.6919  data: 0.5542  max mem: 3180
# Epoch: [1]  [20/25]  eta: 0:00:03    time: 0.7410  data: 0.6027  max mem: 3180
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.7470  data: 0.6085  max mem: 3180
# Epoch: [1] Total time: 0:00:18 (0.7232 s / it)
# train: dice: 0.517677, bce: 0.244188, loss: 0.334439
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:01    time: 0.3834  data: 0.2667  max mem: 3180
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.3074  data: 0.2116  max mem: 3180
# Epoch: [1] Total time: 0:00:00 (0.3078 s / it)
# val: dice: 0.437704, bce: 0.217265, loss: 0.290010, mIoU: 0.521827, mDice: 0.644152
# saving best model to sum_checkpoint.pth
# 0m 20s
# Epoch: [2]  [ 0/25]  eta: 0:00:16    time: 0.6663  data: 0.5333  max mem: 3180
# Epoch: [2]  [10/25]  eta: 0:00:11    time: 0.7923  data: 0.6521  max mem: 3180
# Epoch: [2]  [20/25]  eta: 0:00:03    time: 0.7402  data: 0.5999  max mem: 3180
# Epoch: [2]  [24/25]  eta: 0:00:00    time: 0.7177  data: 0.5778  max mem: 3180
# Epoch: [2] Total time: 0:00:18 (0.7208 s / it)
# train: dice: 0.451084, bce: 0.199043, loss: 0.282216
# LR 0.0005
# Epoch: [2]  [0/3]  eta: 0:00:01    time: 0.4787  data: 0.3552  max mem: 3180
# Epoch: [2]  [2/3]  eta: 0:00:00    time: 0.3904  data: 0.2909  max mem: 3180
# Epoch: [2] Total time: 0:00:01 (0.3910 s / it)
# val: dice: 0.430795, bce: 0.187390, loss: 0.267714, mIoU: 0.522007, mDice: 0.645746
# saving best model to sum_checkpoint.pth
# 0m 20s
# Epoch: [3]  [ 0/25]  eta: 0:00:22    time: 0.9121  data: 0.7650  max mem: 3180
# Epoch: [3]  [10/25]  eta: 0:00:11    time: 0.7436  data: 0.6040  max mem: 3180
# Epoch: [3]  [20/25]  eta: 0:00:03    time: 0.7172  data: 0.5775  max mem: 3180
# Epoch: [3]  [24/25]  eta: 0:00:00    time: 0.7148  data: 0.5735  max mem: 3180
# Epoch: [3] Total time: 0:00:18 (0.7512 s / it)
# train: dice: 0.411124, bce: 0.182184, loss: 0.257734
# LR 0.0005
# Epoch: [3]  [0/3]  eta: 0:00:01    time: 0.5274  data: 0.4003  max mem: 3180
# Epoch: [3]  [2/3]  eta: 0:00:00    time: 0.4097  data: 0.3061  max mem: 3180
# Epoch: [3] Total time: 0:00:01 (0.4102 s / it)
# val: dice: 0.430223, bce: 0.260922, loss: 0.316791, mIoU: 0.512100, mDice: 0.629322
# 0m 20s
# Epoch: [4]  [ 0/25]  eta: 0:00:20    time: 0.8198  data: 0.6816  max mem: 3180
# Epoch: [4]  [10/25]  eta: 0:00:09    time: 0.6386  data: 0.4981  max mem: 3180
# Epoch: [4]  [20/25]  eta: 0:00:03    time: 0.6826  data: 0.5396  max mem: 3180
# Epoch: [4]  [24/25]  eta: 0:00:00    time: 0.7246  data: 0.5806  max mem: 3180
# Epoch: [4] Total time: 0:00:17 (0.7111 s / it)
# train: dice: 0.382426, bce: 0.170658, loss: 0.240541
# LR 0.0005
# Epoch: [4]  [0/3]  eta: 0:00:01    time: 0.3893  data: 0.2645  max mem: 3180
# Epoch: [4]  [2/3]  eta: 0:00:00    time: 0.3105  data: 0.2092  max mem: 3180
# Epoch: [4] Total time: 0:00:00 (0.3109 s / it)
# val: dice: 0.376593, bce: 0.171779, loss: 0.239368, mIoU: 0.586724, mDice: 0.697819
# saving best model to sum_checkpoint.pth
# 0m 19s
# Epoch: [5]  [ 0/25]  eta: 0:00:15    time: 0.6262  data: 0.4840  max mem: 3180
# Epoch: [5]  [10/25]  eta: 0:00:09    time: 0.6154  data: 0.4729  max mem: 3180
# Epoch: [5]  [20/25]  eta: 0:00:03    time: 0.7390  data: 0.5919  max mem: 3180
# Epoch: [5]  [24/25]  eta: 0:00:00    time: 0.7477  data: 0.6005  max mem: 3180
# Epoch: [5] Total time: 0:00:18 (0.7240 s / it)
# train: dice: 0.355644, bce: 0.143844, loss: 0.213738
# LR 0.0005
# Epoch: [5]  [0/3]  eta: 0:00:01    time: 0.3903  data: 0.2640  max mem: 3180
# Epoch: [5]  [2/3]  eta: 0:00:00    time: 0.3137  data: 0.2107  max mem: 3180
# Epoch: [5] Total time: 0:00:00 (0.3141 s / it)
# val: dice: 0.415882, bce: 0.201027, loss: 0.271929, mIoU: 0.515973, mDice: 0.631652
# 0m 19s
# Epoch: [6]  [ 0/25]  eta: 0:00:15    time: 0.6226  data: 0.4813  max mem: 3180
# Epoch: [6]  [10/25]  eta: 0:00:10    time: 0.7098  data: 0.5622  max mem: 3180
# Epoch: [6]  [20/25]  eta: 0:00:03    time: 0.7314  data: 0.5830  max mem: 3180
# Epoch: [6]  [24/25]  eta: 0:00:00    time: 0.7308  data: 0.5818  max mem: 3180
# Epoch: [6] Total time: 0:00:17 (0.7129 s / it)
# train: dice: 0.319302, bce: 0.137064, loss: 0.197203
# LR 0.0005
# Epoch: [6]  [0/3]  eta: 0:00:01    time: 0.3926  data: 0.2648  max mem: 3180
# Epoch: [6]  [2/3]  eta: 0:00:00    time: 0.3220  data: 0.2167  max mem: 3180
# Epoch: [6] Total time: 0:00:00 (0.3224 s / it)
# val: dice: 0.355717, bce: 0.157714, loss: 0.223055, mIoU: 0.609600, mDice: 0.717657
# saving best model to sum_checkpoint.pth
# 0m 19s
# Epoch: [7]  [ 0/25]  eta: 0:00:16    time: 0.6719  data: 0.5270  max mem: 3180
# Epoch: [7]  [10/25]  eta: 0:00:11    time: 0.7940  data: 0.6449  max mem: 3180
# Epoch: [7]  [20/25]  eta: 0:00:03    time: 0.7420  data: 0.5933  max mem: 3180
# Epoch: [7]  [24/25]  eta: 0:00:00    time: 0.7120  data: 0.5645  max mem: 3180
# Epoch: [7] Total time: 0:00:18 (0.7214 s / it)
# train: dice: 0.329938, bce: 0.144343, loss: 0.205589
# LR 0.0005
# Epoch: [7]  [0/3]  eta: 0:00:01    time: 0.4759  data: 0.3494  max mem: 3180
# Epoch: [7]  [2/3]  eta: 0:00:00    time: 0.3904  data: 0.2862  max mem: 3180
# Epoch: [7] Total time: 0:00:01 (0.3909 s / it)
# val: dice: 0.423056, bce: 0.365933, loss: 0.384784, mIoU: 0.510270, mDice: 0.619274
# 0m 19s
# Epoch: [8]  [ 0/25]  eta: 0:00:22    time: 0.9162  data: 0.7650  max mem: 3180
# Epoch: [8]  [10/25]  eta: 0:00:11    time: 0.7612  data: 0.6144  max mem: 3180
# Epoch: [8]  [20/25]  eta: 0:00:03    time: 0.6903  data: 0.5454  max mem: 3180
# Epoch: [8]  [24/25]  eta: 0:00:00    time: 0.6821  data: 0.5373  max mem: 3180
# Epoch: [8] Total time: 0:00:18 (0.7276 s / it)
# train: dice: 0.306965, bce: 0.129296, loss: 0.187927
# LR 0.0005
# Epoch: [8]  [0/3]  eta: 0:00:01    time: 0.5144  data: 0.3906  max mem: 3180
# Epoch: [8]  [2/3]  eta: 0:00:00    time: 0.3981  data: 0.2952  max mem: 3180
# Epoch: [8] Total time: 0:00:01 (0.3986 s / it)
# val: dice: 0.364610, bce: 0.151857, loss: 0.222065, mIoU: 0.601572, mDice: 0.699926
# saving best model to sum_checkpoint.pth
# 0m 20s
# Epoch: [9]  [ 0/25]  eta: 0:00:23    time: 0.9411  data: 0.7886  max mem: 3180
# Epoch: [9]  [10/25]  eta: 0:00:09    time: 0.6655  data: 0.5212  max mem: 3180
# Epoch: [9]  [20/25]  eta: 0:00:03    time: 0.7048  data: 0.5584  max mem: 3180
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.7365  data: 0.5894  max mem: 3180
# Epoch: [9] Total time: 0:00:18 (0.7305 s / it)
# train: dice: 0.302928, bce: 0.135467, loss: 0.190729
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:01    time: 0.3919  data: 0.2627  max mem: 3180
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.3086  data: 0.2063  max mem: 3180
# Epoch: [9] Total time: 0:00:00 (0.3089 s / it)
# val: dice: 0.367240, bce: 0.197488, loss: 0.253506, mIoU: 0.586220, mDice: 0.690407
# 0m 19s
# Epoch: [10]  [ 0/25]  eta: 0:00:16    time: 0.6719  data: 0.5297  max mem: 3180
# Epoch: [10]  [10/25]  eta: 0:00:09    time: 0.6171  data: 0.4735  max mem: 3180
# Epoch: [10]  [20/25]  eta: 0:00:03    time: 0.7058  data: 0.5596  max mem: 3180
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.7035  data: 0.5573  max mem: 3180
# Epoch: [10] Total time: 0:00:17 (0.6882 s / it)
# train: dice: 0.295187, bce: 0.125103, loss: 0.181231
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:01    time: 0.3928  data: 0.2632  max mem: 3180
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.3162  data: 0.2124  max mem: 3180
# Epoch: [10] Total time: 0:00:00 (0.3165 s / it)
# val: dice: 0.374870, bce: 0.185552, loss: 0.248027, mIoU: 0.576142, mDice: 0.679134
# 0m 18s
# Epoch: [11]  [ 0/25]  eta: 0:00:16    time: 0.6794  data: 0.5366  max mem: 3180
# Epoch: [11]  [10/25]  eta: 0:00:09    time: 0.6273  data: 0.4819  max mem: 3180
# Epoch: [11]  [20/25]  eta: 0:00:03    time: 0.7595  data: 0.6122  max mem: 3180
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.7633  data: 0.6163  max mem: 3180
# Epoch: [11] Total time: 0:00:18 (0.7341 s / it)
# train: dice: 0.269279, bce: 0.115491, loss: 0.166241
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:01    time: 0.3887  data: 0.2610  max mem: 3180
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.3120  data: 0.2104  max mem: 3180
# Epoch: [11] Total time: 0:00:00 (0.3124 s / it)
# val: dice: 0.349621, bce: 0.147866, loss: 0.214445, mIoU: 0.603184, mDice: 0.707753
# saving best model to sum_checkpoint.pth
# 0m 20s
# Epoch: [12]  [ 0/25]  eta: 0:00:15    time: 0.6355  data: 0.4901  max mem: 3180
# Epoch: [12]  [10/25]  eta: 0:00:12    time: 0.8198  data: 0.6700  max mem: 3180
# Epoch: [12]  [20/25]  eta: 0:00:03    time: 0.7410  data: 0.5939  max mem: 3180
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.7396  data: 0.5928  max mem: 3180
# Epoch: [12] Total time: 0:00:17 (0.7175 s / it)
# train: dice: 0.274361, bce: 0.117545, loss: 0.169294
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:01    time: 0.3929  data: 0.2613  max mem: 3180
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.3109  data: 0.2076  max mem: 3180
# Epoch: [12] Total time: 0:00:00 (0.3113 s / it)
# val: dice: 0.393132, bce: 0.199497, loss: 0.263397, mIoU: 0.538314, mDice: 0.647848
# 0m 19s
# Epoch: [13]  [ 0/25]  eta: 0:00:15    time: 0.6220  data: 0.4717  max mem: 3180
# Epoch: [13]  [10/25]  eta: 0:00:12    time: 0.8036  data: 0.6553  max mem: 3180
# Epoch: [13]  [20/25]  eta: 0:00:03    time: 0.7225  data: 0.5765  max mem: 3180
# Epoch: [13]  [24/25]  eta: 0:00:00    time: 0.6912  data: 0.5455  max mem: 3180
# Epoch: [13] Total time: 0:00:18 (0.7226 s / it)
# train: dice: 0.309748, bce: 0.162170, loss: 0.210871
# LR 0.0005
# Epoch: [13]  [0/3]  eta: 0:00:01    time: 0.4931  data: 0.3700  max mem: 3180
# Epoch: [13]  [2/3]  eta: 0:00:00    time: 0.3903  data: 0.2899  max mem: 3180
# Epoch: [13] Total time: 0:00:01 (0.3908 s / it)
# val: dice: 0.394215, bce: 0.186426, loss: 0.254996, mIoU: 0.545414, mDice: 0.659799
# 0m 19s
# Epoch: [14]  [ 0/25]  eta: 0:00:23    time: 0.9519  data: 0.7985  max mem: 3180
# Epoch: [14]  [10/25]  eta: 0:00:10    time: 0.7236  data: 0.5760  max mem: 3180
# Epoch: [14]  [20/25]  eta: 0:00:03    time: 0.6778  data: 0.5317  max mem: 3180
# Epoch: [14]  [24/25]  eta: 0:00:00    time: 0.6909  data: 0.5441  max mem: 3180
# Epoch: [14] Total time: 0:00:18 (0.7228 s / it)
# train: dice: 0.316257, bce: 0.136635, loss: 0.195910
# LR 0.0005
# Epoch: [14]  [0/3]  eta: 0:00:01    time: 0.5061  data: 0.3820  max mem: 3180
# Epoch: [14]  [2/3]  eta: 0:00:00    time: 0.4002  data: 0.2987  max mem: 3180
# Epoch: [14] Total time: 0:00:01 (0.4007 s / it)
# val: dice: 0.427626, bce: 0.189509, loss: 0.268088, mIoU: 0.527625, mDice: 0.640824
# 0m 19s
# Epoch: [15]  [ 0/25]  eta: 0:00:21    time: 0.8513  data: 0.7094  max mem: 3180
# Epoch: [15]  [10/25]  eta: 0:00:09    time: 0.6616  data: 0.5177  max mem: 3180
# Epoch: [15]  [20/25]  eta: 0:00:03    time: 0.6950  data: 0.5495  max mem: 3180
# Epoch: [15]  [24/25]  eta: 0:00:00    time: 0.7258  data: 0.5798  max mem: 3180
# Epoch: [15] Total time: 0:00:17 (0.7142 s / it)
# train: dice: 0.295491, bce: 0.128722, loss: 0.183756
# LR 0.0005
# Epoch: [15]  [0/3]  eta: 0:00:01    time: 0.3806  data: 0.2521  max mem: 3180
# Epoch: [15]  [2/3]  eta: 0:00:00    time: 0.3052  data: 0.2022  max mem: 3180
# Epoch: [15] Total time: 0:00:00 (0.3056 s / it)
# val: dice: 0.344988, bce: 0.160578, loss: 0.221433, mIoU: 0.603556, mDice: 0.708835
# 0m 19s
# Epoch: [16]  [ 0/25]  eta: 0:00:15    time: 0.6339  data: 0.4898  max mem: 3180
# Epoch: [16]  [10/25]  eta: 0:00:09    time: 0.6174  data: 0.4724  max mem: 3180
# Epoch: [16]  [20/25]  eta: 0:00:03    time: 0.7112  data: 0.5645  max mem: 3180
# Epoch: [16]  [24/25]  eta: 0:00:00    time: 0.7165  data: 0.5699  max mem: 3180
# Epoch: [16] Total time: 0:00:17 (0.6955 s / it)
# train: dice: 0.271418, bce: 0.113994, loss: 0.165944
# LR 0.0005
# Epoch: [16]  [0/3]  eta: 0:00:01    time: 0.3841  data: 0.2578  max mem: 3180
# Epoch: [16]  [2/3]  eta: 0:00:00    time: 0.3125  data: 0.2089  max mem: 3180
# Epoch: [16] Total time: 0:00:00 (0.3128 s / it)
# val: dice: 0.336596, bce: 0.158982, loss: 0.217595, mIoU: 0.609389, mDice: 0.706447
# 0m 18s
# Epoch: [17]  [ 0/25]  eta: 0:00:16    time: 0.6718  data: 0.5268  max mem: 3180
# Epoch: [17]  [10/25]  eta: 0:00:09    time: 0.6643  data: 0.5185  max mem: 3180
# Epoch: [17]  [20/25]  eta: 0:00:03    time: 0.7143  data: 0.5678  max mem: 3180
# Epoch: [17]  [24/25]  eta: 0:00:00    time: 0.7119  data: 0.5658  max mem: 3180
# Epoch: [17] Total time: 0:00:17 (0.6992 s / it)
# train: dice: 0.250777, bce: 0.107709, loss: 0.154921
# LR 0.0005
# Epoch: [17]  [0/3]  eta: 0:00:01    time: 0.3852  data: 0.2575  max mem: 3180
# Epoch: [17]  [2/3]  eta: 0:00:00    time: 0.3085  data: 0.2059  max mem: 3180
# Epoch: [17] Total time: 0:00:00 (0.3088 s / it)
# val: dice: 0.393556, bce: 0.168178, loss: 0.242553, mIoU: 0.553877, mDice: 0.658795
# 0m 18s
# Epoch: [18]  [ 0/25]  eta: 0:00:15    time: 0.6031  data: 0.4576  max mem: 3180
# Epoch: [18]  [10/25]  eta: 0:00:10    time: 0.7316  data: 0.5826  max mem: 3180
# Epoch: [18]  [20/25]  eta: 0:00:03    time: 0.7174  data: 0.5701  max mem: 3180
# Epoch: [18]  [24/25]  eta: 0:00:00    time: 0.7121  data: 0.5652  max mem: 3180
# Epoch: [18] Total time: 0:00:17 (0.6941 s / it)
# train: dice: 0.253160, bce: 0.104596, loss: 0.153622
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:01    time: 0.3977  data: 0.2695  max mem: 3180
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.3098  data: 0.2085  max mem: 3180
# Epoch: [18] Total time: 0:00:00 (0.3102 s / it)
# val: dice: 0.359201, bce: 0.201641, loss: 0.253636, mIoU: 0.583965, mDice: 0.688797
# 0m 18s
# Epoch: [19]  [ 0/25]  eta: 0:00:15    time: 0.6389  data: 0.4974  max mem: 3180
# Epoch: [19]  [10/25]  eta: 0:00:12    time: 0.8216  data: 0.6742  max mem: 3180
# Epoch: [19]  [20/25]  eta: 0:00:03    time: 0.7311  data: 0.5853  max mem: 3180
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.7052  data: 0.5600  max mem: 3180
# Epoch: [19] Total time: 0:00:17 (0.7128 s / it)
# train: dice: 0.226095, bce: 0.089777, loss: 0.134762
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.4723  data: 0.3430  max mem: 3180
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.3850  data: 0.2815  max mem: 3180
# Epoch: [19] Total time: 0:00:01 (0.3855 s / it)
# val: dice: 0.320409, bce: 0.152997, loss: 0.208243, mIoU: 0.631448, mDice: 0.730469
# saving best model to sum_checkpoint.pth
# 0m 20s
# Best val loss: 0.208243

# %%
# !python main.py --skip sum --coco_path "{PATH_TO_COCO}"  --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/MUPPARAPU_SAIKOUSHIK_114999629_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='sum', checkpoint='sum_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.6314481496810913 , mDice:0.7304691672325134

# %% [markdown]
# ## Submission guidelines
# ---
#
#
#
# The submission structure should look like:
#
# IMPORTANT: Remove the images/ folder, and any CHECKPOINT files.
#
#
# ```
# {last name}_{first name}_{sbu id}_hw2/
# ├── part1/
# │   └── ...
# ├── part2/
# │   └── ...
# ├── part3/
# │   ├── CSE527_23F_HW3_P3.ipynb
# │   └── unet/
# │       ├── utils/
# │       │   ├── ...
# │       │   └── ...
# │       ├── coco.py
# │       ├── main.py
# │       ├── transforms.py
# │       └── unet.py
# ```
#
#
# Follow instructions in part1's submission guidelines to generate your complete submission
